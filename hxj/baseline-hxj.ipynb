# %% [markdown]
# # 导入相关包

# %%
# 导入相关包
import os
import pathlib as pl
import pandas as pd
import numpy as np
import re
from io import StringIO
from datetime import datetime 
import time
from IPython.core.interactiveshell import InteractiveShell
from tqdm.autonotebook import *
import collections
import functools
from fuzzywuzzy import fuzz

# import pdfplumber
tqdm.pandas()
InteractiveShell.ast_node_interactivity = "all"
sys.path.append("..")

# %% [markdown]
# # PDF解析原始数据
# ## 加载数据并采用pdfplumber抽取PDF中的文字和表格

# %%
# 数据准备(train_output文件中格式有点问题，需要提前用excel或者wps打开然后另存为excel文件)
train_outputs = pd.read_excel('../datasets/train_output.xlsx')

# 获取pdf中文字和表格
def extract_pdf_content(pdf_path):
    text_list = []
    table_list = []
    with pdfplumber.open(pdf_path) as pdf:
        for index_page in np.arange(0, len(pdf.pages), 1):
            # 读取多页
            page = pdf.pages[index_page]   # 第n页的信息
            text = page.extract_text()
            text_list.append(text)
            table = page.extract_tables()
            for t in table:
                table_list.append(t)
    return text_list, table_list

def get_dir_file(path):
    '''
    输入文件夹位置，输出整理好的dataframe
    '''
    path_list = os.listdir(path)
    id_list = []
    file_path_list = []
    text_list = []
    table_list = []
    for i in tqdm(path_list):
        if '.PDF' in i:
            file_path = path + i
            id_list.append(int(i.split('.')[0]))
            file_path_list.append(file_path)
            try:
                text_temp, table_temp = extract_pdf_content(file_path)
            except Exception:
                print('此pdf无法读取')
                text_temp, table_temp = [], []
            text_list.append(text_temp)
            table_list.append(table_temp)
            
    df = pd.DataFrame()
    df['sample_id'] = id_list
    df['file_path'] = file_path_list
    df['text'] = text_list
    df['tabel'] = table_list
    df = df.sort_values('sample_id')
    return df

# 文件处理太慢，可持续化保存文件
train_path = '../datasets/train.csv'
if os.path.exists(train_path):
    train_df = pd.read_csv(train_path)
else:
    train_df = get_dir_file('datasets/train_data/')
    train_df.to_csv(train_path,index=False)
    train_df = pd.read_csv(train_path)

test_path =  '../datasets/test.csv'
if os.path.exists(test_path):
    test_df = pd.read_csv(test_path)
else:
    test_df = get_dir_file('datasets/test_data/')
    test_df.to_csv(test_path,index=False)
    test_df = pd.read_csv(test_path)

train_outputs.head(2)
train_df.head(2)
test_df.head(2)
# Out:
#    sample_id       认购日期        理财产品名称     产品发行方名称    理财类型  认购金额(万元)  \
# 0          1 2019-03-27         汇聚金1号  中融国际信托有限公司      信托   10000.0
# 1          1 2019-03-27  招商银行步步生金8699        招商银行  银行理财产品     200.0
#
#        产品起息日      产品到息日  产品期限  资金来源    实际购买公司名称 实际购买公司和上市公司关系 买卖方是否有关联关系  \
# 0 2019-03-27 2019-09-23  180天  自有资金  恒生电子股份有限公司          公司本身          否
# 1 2019-03-27        NaT   NaN  自有资金  恒生电子股份有限公司          公司本身          否
#
#         公告日期
# 0 2019-04-25
# 1 2019-04-25
#    sample_id                  file_path  \
# 0          1  datasets/train_data/1.PDF
# 1          2  datasets/train_data/2.PDF
#
#                                                 text  \
# 0  ['                                            ...
# 1  ['                                            ...
#
#                                                tabel
# 0  [[['', None, None, '', None, None, '', None, N...
# 1  [[['', None, None, '', None, None, '', None, N...
#    sample_id                     file_path  \
# 0      11188  datasets/test_data/11188.PDF
# 1      11189  datasets/test_data/11189.PDF
#
#                                                 text tabel
# 0  ['北京京西文化旅游股份有限公司监事会\n \n \n关于使用部分闲置募集资金购买理财产品的...    []
# 1  ['北京京西文化旅游股份有限公司 \n监事会关于使用部分自有资金购买理财产品的意见 \n根据...    []

# %%
# 构造训练集验证集
train_df = train_df.sample(frac=1, random_state=1017)
val_df = train_df[:1800]
train_df = train_df[1800:]

# %%
######计算文本位置长度#############
def len_count(my_list,my_str):
    my_len=0
    for i in my_list:
        my_len=my_len+len(i)
    my_len=my_len+(len(my_list)-1)*len(my_str)
    return my_len


######基于冒号做文本拼接与分割####效果优
def maohao_cat(text):
    text=text.replace(r"\n","^")
    text=text.replace(r"', '","^")
    text=text.replace(' ','')
    text=text.replace('（','(').replace('）',')').replace('；','^')     ###############;直接去掉,有极个别答案(答案中出现了引号)将会收到负反馈，多数正反馈
    text=re.sub('\^[1-9]\^','^',text)
    text=re.sub('\^\-[1-9]\-\^','^',text)
    text=re.sub("[（][^）]*?[\^]*$",'',text)
    text=re.sub('[，]*$','',text)
    pos_word=["名称","期限","年","月","日","时间","产品","资金","金额","天","来源","总额","类型","元","关系","无关","不存在关"]
    if '^' not in text:
        return 
    my_list=text.split("^")
    my_str=''
    str_list=[]
    # for i in my_list:
    #     if "：" not in i and ":" not in i and "无关" not in i and "不存在关" not in i and "名称" not in my_str:
    #         my_str=my_str+i
    #         # if len(i)<=6:
    #         #     str_list.append(my_str)      #############解决最后一行被后函数因字数过长舍弃的办法
    #         #     continue
    #     else:
    #         str_list.append(my_str)
    #         my_str=i
    
    for i in my_list:
        if "：" not in i and ":" not in i and len(re.sub('[^\u4e00-\u9fa5]*','',i))<5:
            my_str=my_str+i
            # if "不存在关" in my_str:
            #     str_list.append(my_str)
            #     my_str=''
            # if len(i)<=6:
            #     str_list.append(my_str)      #############解决最后一行被后函数因字数过长舍弃的办法
            #     continue
        else:
            str_list.append(my_str)
            my_str=i
    
    str_list.append(my_str)
    # print(my_list)
    # print('-----')
    # print(str_list)
    # print('-----')
    cat_text=''
    # print(str_list)
    for i in str_list:
        cat_text=cat_text+i+r'^'
        # print(cat_text)
    # print(cat_text.replace(r'^','\n'))
    return cat_text

    

        





######寻找文本中的答案##############
####以如下及冒号行做切片#############
def wjc_spl(text):
    spl1=[]      ###如下切片
    maohao=3  ####设定冒号出现次数阈值
    zishu=30   ####设定单行冒号后字数阈值
    my_str=""
    text=maohao_cat(text)    #########调用函数做text正规化
    spl2=[]      ###行切片
    spl3=[]
    neg_word=[]
    pos_word=["名称","期限","年","月","日","时间","产品","资金","金额","天","来源","总额","类型","元","关系","额","金","受托","签约银行"]
    # pos_word=["名称"]
    # print(len(text))
    if text==None:
        return -1,-1,-1
    text=text.replace(r"\n","^")
    # print(len(text))
    text=text.replace(r"', '","^")    ######解决换页符被置为', '的问题
    # print(len(text))
    text=text.replace(' ','')
    text=text.replace('（','(').replace('）',')').replace(':','：').replace('如^下：','如下：').replace('如下^：','如下：')
    # print(len(text))
    # print(text[:10000])
    if "如下：" not in text:
        return -1,-1,-1
    else:
        move=[]
        spl1=text.split("如下：")   #####首次切割####
        # print(len_count(spl1,'如下：'))
        # print(len(spl1[0])+len(spl1[1]))
        my_len=len(spl1[0])+len('如下：')
        spl1=spl1[1:]              ######第一次如下前的内容不关心##########
        len_list=[]
        tag1=[]
        # print(spl1)
        for i in spl1:
            len_list.append(len(i))
            if i.count("：")<=maohao:
                # print('aaaaaaa',len(len_list))
                tag1.append(len(len_list))
                move.append(i)
        # move=list(set(move))
        for x in move:
            # print('pppppppppppppppppppppppppppp')
            # print(x)
            spl1.remove(x)    ####去除冒号过少的部分切片
                
        # print(my_len+0)
        # print(spl1)
        for i in spl1:
            test=i.split('^')
            #print(test[10])
            for j in test:
                spl2.append(j)
            
        # print(spl2[100])
        move=[]
        for i in spl2:
            #print(i)
            if i.count("：")!=1 and i.count(":")!=1:
                # print(i.count("："))
                move.append(i)    ####以行做切片，去除单行里非只有一个冒号的行
        for x in move:
            # print(x)
            spl2.remove(x)
        # print(spl2[0])
        move=[]
        for i in spl2:
            judge1=re.sub('[a-zA-Z]','',i.split("：")[-1])
            judge1=re.sub(r"\d",'',judge1)
            judge1=re.sub(r'”','',judge1)
            judge1=re.sub(r'“','',judge1)
            judge1=re.sub(r'（','',judge1)
            judge1=re.sub(r'）','',judge1)
            # print(len(judge1))
            if len(judge1)>=zishu or len(judge1)<1:     #######去除冒号后关心字段所提中文内容过长或过短的行
                move.append(i)
                # print(i)
        for x in move:
            # print(x)
            spl2.remove(x)
        # print(spl2)
        move=[]
        # print(spl2)
        # print('-----------')

        # print(spl2)
        if spl2==[]:
            # print('该文本变量做行切片结果为空')
            return -1,-1,-1

        for i in spl2:
            x=0
            for j in pos_word:
                judge2=i.split("：")[0]      ########舍弃冒号前（分类字段）不包含pos_word的行
                if j not in judge2:
                    x=x+1
                if x==len(pos_word):
                    # print(i)
                    move.append(i)
            new_move=list(set(move))
            # print(new_move)
        for x in new_move:
            # print(x)
            spl2.remove(x)
            
        # print(spl2)

        


    
    tag1=0
    key_pos_word=['名称']                 ############计算一个pdf生成的dataframe一共需要几行，及每行需要多少列###########
    x=1
    ele_times=[]
    judge3=0
    for i in spl2:
        for j in key_pos_word:
            if j not in i:
                x=x+1                     ############若不含名称字段则结果会是实际+1###############
            else:
                ele_times.append(x)
                x=1
    
            # print(i)
            # print(x)
    ele_times.append(x)

    
    # print(ele_times)
    if len(ele_times)>1:
        mo_times=ele_times[0]+ele_times[-1]-1
        # print(type(mo_times))
        ele_times=ele_times[1:-1]
        ele_times.append(mo_times)
    else:
        test=0
        # print(len(spl2))
        # print(ele_times[0])
        if len(ele_times)==1 and ele_times[0]==len(spl2)+1:
            # print("不含名称字段")                              ##############此处需处理，或者返回一个标记以后处理  冒号行不包含名称字段的情况
            tag1=1
    

    ele_times1=ele_times
    # print(ele_times)
    # print(type(ele_times))

    tag2=0
    key_pos_word=['金额']                 ############计算一个pdf生成的dataframe一共需要几行，及每行需要多少列###########
    x=1
    ele_times=[]
    judge3=0
    for i in spl2:
        for j in key_pos_word:
            if j not in i:
                x=x+1                     ############若不含金额字段则结果会是实际+1###############
            else:
                ele_times.append(x)
                x=1
    
            # print(i)
            # print(x)
    ele_times.append(x)
    # print(ele_times)
    if len(ele_times)>1:
        mo_times=ele_times[0]+ele_times[-1]-1
        # print(type(mo_times))
        ele_times=ele_times[1:-1]
        ele_times.append(mo_times)
    else:
        test=0
        # print(len(spl2))
        # print(ele_times[0])
        if len(ele_times)==1 and ele_times[0]==len(spl2)+1:
            # print("不含金额字段")                              ##############此处需处理，或者返回一个标记以后处理  冒号行不包含金额字段的情况
            tag2=1
    
    ele_times2=ele_times
    # print(ele_times2)

    # print('---')

    

    if len(spl2)<=2:
        return -1,-1,-1

    

    # print(ele_times2)
    # if len(spl2)==1 and spl2[0]=='':
    #     return
    # if len(spl2)==1:
    #     spl2[0].replace(' ','')
   
    return spl2,ele_times1,tag1     ######仅返回“关心”的行切片    #############注意返回变量可能造成函数无法执行



def cut_list(text):
    spl2,ele_times1,tag1=wjc_spl(text)
    # print(spl2)
    # print(ele_times1)
    # print(tag1)
    my_list=[]
    if tag1==0:
        for i in ele_times1:
            # print(i)
            get=spl2[0:i]
            my_list.append(get)
            spl2=spl2[i:]
    else:
        return 0
    # print(my_list)
    return my_list



def get_mc(text):
    # my_list=cut_list(text)
    mc_list=[]
    my_list=cut_list(text)
    if my_list==0:
        return 
    else:
        my_list=cut_list(text)

        for i in my_list:
            this_str=i[0]
            if "名" not in this_str or "受托方" in this_str or "公司名称" in this_str:
                continue
            index=this_str.index("：")
            this_str=this_str[index+1:].replace('。','').replace('；','').replace(';','').replace('、','')
            mc_list.append(this_str)
            # print(mc_list)
    if mc_list ==[]:
        return
    return mc_list



def spl2_iswm(text):
    spl2,ele_times1,tag1=wjc_spl(text)
    # print(spl2)
    # print(ele_times1)
    # print(tag1)
    my_list=[]
    if tag1==1:
        return "无名称"
    else:
        return 



# def get_all(text):
#     # my_list=cut_list(text)
#     mc_list=[]
#     my_list=cut_list(text)
#     str_money=''
#     str_len_time=''
#     str_fxf=''    #####发行方####
#     time_list=[]
#     all_list=[]
#     part_list=[]
#     if my_list==0:
#         return 
#     else:
#         my_list=cut_list(text)

#         for i in my_list:
#             for j in i:
#                 if "金额" in j or "总额" in j or "元" in j or ("币种" not in j and "人民币" in j):                     ########此处因可能造成晒错，所以统一遍历
#                     str_money=j
#                     part_list.append(str_money)
#                     continue
#                 if "期限" in j:
#                     str_len_time=j
#                     part_list.append(str_len_time)
#                 if "无关" in j or "不存在关" in j or "受托方" in j:
#                     str_fxf=j
#                     part_list.append(str_fxf)
#                 if "年" in j and "月" in j and "日" in j:
#                     time_list.append(j)
#                 part_list.append(time_list)
#                 all_list.append(part_list)
#             part_list=[]
#     print('---------')
#     print(all_list)
#     if all_list==[]:
#         return 
#     return all_list





# str_test=val_df['text'][660]
# print(type(val_df['text'][201]))
# spllll=wjc_spl(str_test)
#print(spllll)

# def zuhe(text):
#     my_str=maohao_cat(text)
#     spllll=wjc_spl(mystr)
#     return spllll


###test模块##########
# str_test=val_df['text'][201]
# # mystr=maohao_cat(str_test)
# # print(mystr)
# # spllll=wjc_spl(str_test)
# # cut_list(str_test)
# get_all(str_test)
# # print(times1)



############全test模块##########
val_text=val_df[['sample_id','text']]
# val_text['sample_id']=val_df['sample_id'].astype(str)
val_text['提取文本关键区域'] = val_df.progress_apply(lambda row: wjc_spl(row['text']), axis=1)
# df["列名"]=df.apply(lambda x:方法名(x,入参2),axis=1)
suc_val_text=val_text[val_text['提取文本关键区域'].notnull() & (val_text['提取文本关键区域'] != "")]
print('一共有',val_text.sample_id.size,'行')
print('其中text抽取了',suc_val_text.提取文本关键区域.size,'行')

suc_val_text['mc'] = val_df.progress_apply(lambda row: get_mc(row['text']), axis=1)
suc_val_text['以名称拆分的list'] = val_df.progress_apply(lambda row: cut_list(row['text']), axis=1)

suc_val_text=suc_val_text.dropna()


##########测试无名称的sampleid######    #######仅测试冒号无缺失情况
wm_val_text=val_df[['sample_id','text']]
wm_val_text['无名称标记']=val_df.progress_apply(lambda row: spl2_iswm(row['text']), axis=1)
wm_val_text=wm_val_text[wm_val_text['无名称标记'].notnull() & (wm_val_text['无名称标记'] != "")]
wm_val_text['提取文本关键区域'] = val_df.progress_apply(lambda row: wjc_spl(row['text']), axis=1)

wm_val_text=wm_val_text.dropna()

# print(len(suc_val_text.iloc[858,3]))
# print(suc_val_text.iloc[858,3])
# suc_val_text = suc_val_text[suc_val_text['提取文本关键区域'].str.contains("万")]
# letters=0
# letter=''
# for i in suc_val_text['提取文本关键区域']:
#     if j in i:
#         letter=letter+j
#     if '万' in letter:
#         letters=letters+1
# print('万', letters)
# print(type(suc_val_text.iloc[1,3]))
# Out:
# 100%|██████████| 1800/1800 [00:02<00:00, 759.67it/s]
#   2%|▏         | 38/1800 [00:00<00:04, 378.96it/s]一共有 1800 行
# 其中text抽取了 1800 行
# 100%|██████████| 1800/1800 [00:03<00:00, 483.06it/s]
# 100%|██████████| 1800/1800 [00:02<00:00, 754.36it/s]
# 100%|██████████| 1800/1800 [00:02<00:00, 756.35it/s]
# 100%|██████████| 1800/1800 [00:02<00:00, 797.68it/s]

# %%
#text=text.replace(r'[ ]+',' ').replace('\r','^')
def get_title(text):
    global title_num_char
    title_list=[]
    title_type_list=[]
    text_start_iter_list=[]
    text_end_iter_list=[]
 
    for item in title_num_char:
        pattern = re.compile(item+"[0-9A-Za-z\u4e00-\u9fa5 ()\[\]（）【】：:]*?[\^]")
        pattern = re.compile(item+"[0-9A-Za-z\u4e00-\u9fa5 ()\[\]（）【】：:]*?[\^]")
        #pattern = re.compile(item+r"[ ]*?[^ ]+?[ ]")
        #pattern = re.compile(item+"[0-9A-Za-z\u4e00-\u9fa5 ()[]（）【】][]")#*?[\^]
        tmp=pattern.finditer(text)
        for i in tmp:
            title_list.append(i.group())
            text_start_iter_list.append(i.span(0)[0])
            title_type_list.append(1)
            text_end_iter_list.append(i.span(0)[1])

    # for item in title_list:
    for item in s_title_num_char:
        # pattern = re.compile(item+r"[ ]*?[ ]*?[\d][^ ]+?:?[ ]?") 
        # pattern = re.compile(item+"[0-9A-Za-z\u4e00-\u9fa5\^ ]*")
        # pattern = re.compile(item+'[0-9\u4e00-\u9fa5()[]（）【】*?[\^]]')*?[\^]
    #    pattern = re.compile(item+r"[\d]*?\u4e00-\u9fa5+[ ]")
        pattern = re.compile(item+"[0-9A-Za-z\u4e00-\u9fa5\"(\.*?)\" ()\[\]（）【】：:]*?[\^]")
        tmp=pattern.finditer(text)
        for i in tmp:
            title_list.append(i.group())
            text_start_iter_list.append(i.span(0)[0])
            title_type_list.append(1)
            text_end_iter_list.append(i.span(0)[1])

    title_list.append("引言")
    title_type_list.append(1)
    text_start_iter_list.append(0)
    text_end_iter_list.append(0)

    result_df=pd.DataFrame([title_list,title_type_list,text_start_iter_list,text_end_iter_list]).T.sort_values(by=2).reset_index(drop=True)
    # print(result_df)
    return result_df

def get_title_text(text,title_df):
    # print(title_df)
    title_1_df=title_df[title_df[1]==1]
    text_iter_list=[]
    text_list=[]
    # print(title_1_df)
    for iter1,iter2 in title_1_df[[2,3]].values:
        # print(iter1)
        if(len(text_iter_list)!=0):
            text_iter_list.append(iter1)
        text_iter_list.append(iter2)
    # text_iter_list.append(text_iter_list[len(text_iter_list)-1])
    text_iter_list.append(len(text))
    for index in range(int(len(text_iter_list)/2)):
        text_list.append(text[text_iter_list[2*index]:text_iter_list[2*index+1]])
    
    title_1_df[4]=text_list

    return title_1_df.reset_index(drop=True)

#from fuzzywuzzy import fuzz
def judge_title(sample_id=0,text=r"test\n"):
    # print(text)
    text=text.replace(r"\n","^").replace(r'[ ]+',' ')
    title_df=get_title(text)
    title_df["sample_id"]=[sample_id for x in range(title_df.shape[0])]
    # print(title_df)`
    title_1_df=get_title_text(text,title_df)[["sample_id",0,1,2,3,4]]

    global val_df
    global train_outputs
    val_true_name=train_outputs[train_outputs["sample_id"]==sample_id]["理财产品名称"]
    
    index=0
    neg_index=[]
    for title_des in title_1_df[0].values:
        flag=True
        for item1 in title_pos_words:
            if re.search(item1,title_des) is not None:
                flag=False
                break
        if flag:
            for item in title_neg_words:
                if re.search(item,title_des) is not None:
                    neg_index.append(index)
                    break
        index+=1
    return title_1_df.reset_index(drop=True).drop(neg_index)
    # print(title_list)

def get_judge_title_result(val_df):

    judge_title_result=None


    for sample_id,text in tqdm(val_df[["sample_id","text"]].values):
        # print(sample_id)
        # print(text)
        judge_title_result= judge_title(sample_id,text) if judge_title_result is None else pd.concat([judge_title_result,judge_title(sample_id,text)])
    
    return judge_title_result

title_num_char=["一、","二、","三、","四、","五、","六、","七、","八、","九、","十、","十一、","十二、","十三、","十四、","十五、"]
s_title_num_char=["（一）","（二）","（三）","（四）","（五）","（六）","（七）","（八）","（九）","（十）","（十一）","（十二）","（十三）","（十四）","（十五）"]
s_title_num_char.extend(["[(]一[)]","[(]二[)]","[(]三[)]","[(]四[)]","[(]五[)]","[(]六[)]","[(]七[)]","[(]八[)]","[(]九[)]","[(]十[)]","[(]十一[)]","[(]十二[)]","[(]十三[)]","[(]十四[)]","[(]十五[)]", \
    '1、', '2、', '3、', '4、', '5、', '6、', '7、', '8、', '9、', "《", "<", ">", "》", "\“", "\""
    ])

title_pos_words=[]#"含本次","含本公告","公司及控股子公司",]#,"继续使用","新购买","近期","信托","计划","项目",'']
title_neg_words=["备查","日前","过去","履行","审批","程序","风险","措施","影响","累计","赎回","意见","十二个月内","公告前","报备文件","前期","截至","到期","已到期",'前次',"控制","本公告日前","分析","披露","主体","关联","条款","合同","说明","协议"]
# val_judge_title_result=get_judge_title_result(val_df)
# test_judge_title_result=get_judge_title_result(test_df)
# judge_title_result.to_excel("训练集段落标题分类结果.xlsx",index=None)

# 获取潜在标题
def extra_potential_line(df):
    ret = get_judge_title_result(df)
    return ret[['sample_id', 0]].values.tolist()

# 过滤潜在标题
def filter_line(lines):
    def exclude(line):
        exclude = ['产品情况', '产品.*：', '产品性质：']
        for ex in exclude:
            if re.search(ex, line):
                return True

    ret = []
    for [sample_id, line] in lines:
        if not exclude(line):
            ret.append([sample_id, line])

    return ret

# 给定数据集，获取带有产品名称的所有行
def get_line_container_product(df):
    return filter_line(extra_possible_line(df))

# 给定行，计算有几行是有效的
def count_valid_line(all_titles):
    answer = list(set(train_outputs['理财产品名称'].tolist()))
    statis = collections.defaultdict(int)

    for [_, title] in all_titles:
        for a in answer:
            if a == '理财产品' or a == '收益凭证' or a == '银行理财' or a == '银行理财产品' or len(str(a)) < 4:
                continue

            title = title.replace('（', '').replace('）', '')
            a = str(a).replace('（', '').replace('）', '')

            if title.find(str(a)) != -1:
                statis['ok'] += 1
                # print(title + '|=|' + str(a))

    return statis['ok']

def test_extra_possible_line():
    lines = extra_potential_line(wm_val_text)

    n = count_valid_line(lines)
    print('提取的标题的有效答案: %d' % n)

    lines = filter_line(lines)
    k = count_valid_line(lines)
    print('过滤完成后的有效行数: %d' % k)

    df = pd.DataFrame(lines, columns=['sample_id', '产品名称']) 
    print(df)
    
    return df


test_extra_possible_line()
# Out:
# 100%|██████████| 93/93 [00:00<00:00, 93.58it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-7ce8551fcf27> in <module>
#     175
#     176
# --> 177 test_extra_possible_line()
#
# <ipython-input-75-7ce8551fcf27> in test_extra_possible_line()
#     162     lines = extra_potential_line(wm_val_text)
#     163
# --> 164     n = count_valid_line(lines)
#     165     print('提取的标题的有效答案: %d' % n)
#     166
#
# <ipython-input-75-7ce8551fcf27> in count_valid_line(all_titles)
#     151
#     152             title = title.replace('（', '').replace('）', '')
# --> 153             a = a.replace('（', '').replace('）', '')
#     154
#     155             if title.find(str(a)) != -1:
#
# AttributeError: 'int' object has no attribute 'replace'

# %% [markdown]
# # 数据处理
# ## 抽取整体数据（一个sampleid内此字段内容都相同）
# ## 公告时间，实际购买公司

# %%
# Out:
# 100%|██████████| 1800/1800 [00:02<00:00, 775.70it/s]
#   2%|▎         | 45/1800 [00:00<00:03, 439.59it/s]一共有 1800 行
# 其中text抽取了 1800 行
# 100%|██████████| 1800/1800 [00:03<00:00, 514.07it/s]

# %%
# 找到关键字在文本中的位置
def find_pos_in_text(text, keys, sample_id = 0):
    ret = []

    if not keys or len(keys) == 0 or not text:
        return None

    textWithArrow = re.sub(' +', ' ', text).replace(r'\n', '^').replace(' ', '^')
    textWithoutWhite = textWithArrow.replace('^', '')

    # 每个非空词的前缀空格个数
    seq, totalSpace = 0, 0
    preleadingSpaceDict = collections.defaultdict(int)
    for i in range(len(textWithArrow)):
        if (textWithArrow[i]) == '^':
            totalSpace += 1
            preleadingSpaceDict[seq] = totalSpace
        else:
            preleadingSpaceDict[seq] = totalSpace
            seq += 1        

    for key in keys:
        nkey = str(key).replace('(', r'\(').replace(')', r'\)').replace('[', r'\[').replace(']', r'\]')
        for it in re.finditer(nkey, textWithoutWhite):
            ret.append([key, it.span()[0]+preleadingSpaceDict[it.span()[0]], \
                it.span()[1]+preleadingSpaceDict[it.span()[1]], sample_id])

    if not len(ret):
        return None

    ret.sort(key = lambda x: x[1])

    return ret

_ok = 0
_fail = 0
def test_find_pos_in_text(sample_df, key_df):
    def valid_pos(train_pos):
        global _ok
        global _fail
        if not train_pos or len(train_pos) == 0:
            return

        for pos in train_pos:
            df = sample_df[sample_df['sample_id'] == pos[3]]
            text = re.sub(' +', ' ', df['text'].values[0]).replace(r'\n', '^')
            if text[pos[1]:pos[2]].replace(' ', '').replace('^', '') == pos[0]:
                _ok += 1
            else:
                print('sample_id=%s, 位置%d-%d, 长跑=%s, 提取到的内容=%s' % \
                    (pos[3], pos[1], pos[2], pos[0], text[pos[1]:pos[2]]))
                _fail +=1

    # 找到所有的key
    all_key = collections.defaultdict(list)
    def to_all_key(dict, row):
        dict[row['sample_id']] = row['mc']
    key_df.progress_apply(lambda row: to_all_key(all_key, row), axis=1)

    for sample_id in all_key:
        df = sample_df[sample_df['sample_id'] == sample_id]
        if len(df['text'].values) == 0:
            continue
        ret = find_pos_in_text(df['text'].values[0], all_key[sample_id], sample_id)
        valid_pos(ret)
        print(ret)
    
    print('成功: %d, 失败: %d' % (_ok, _fail))

test_find_pos_in_text(val_df, suc_val_text)
# Out:
# 100%|██████████| 858/858 [00:00<00:00, 45136.25it/s]
# [['中国建设银行河南分行“乾元”保本型2017年第41期理财产品', 615, 647, 2974], ['蕴通财富•日增利60天', 839, 852, 2974], ['蕴通财富•日增利60天', 839, 852, 2974], ['蕴通财富•日增利60天', 1043, 1056, 2974], ['蕴通财富•日增利60天', 1043, 1056, 2974]]
# [['中国工商银行保本型法人91天稳利人民币理财产品', 472, 497, 888], ['中国工商银行保本型法人91天稳利人民币理财产品', 529, 554, 888]]
# [['结构性存款', 312, 317, 5913], ['结构性存款', 610, 615, 5913], ['结构性存款', 849, 856, 5913], ['结构性存款', 887, 894, 5913]]
# 成功: 3336, 失败: 0

# %% [markdown]
# # 判断文本是否包含表格

# %%
def is_section_contain_row(section, row, sample_id = 0, statis = None):
    # 有些文件出现', '，其实是个换行的位置!!!
    section = section.replace("', '", r'\n').replace(' ', '')
    # print(section)

    # 用\n分割表头
    ret = []
    for col in row:
        if col == None or len(col) == 0:
            continue
        ret.append(col.split("\n"))

    def escape_reg(r):
        return r.replace(' ', '').replace("\n", '').replace('(', r'[(]').replace(')', r'[)]')

    keys = []
    for row in ret:
        keys += row
    # 都不行，用乱序匹配多行文本
    key_str = escape_reg(r''.join(keys))
    if re.search('.*：', key_str) != None:
        statis['regex'] += 1
        # todo: 是否要判断这个表格？
        return False

    all_lines = section.split(r'\n')
    for i in range(len(all_lines)):
        line_str = ''
        k = 1
        while len(line_str) < len(key_str) and i + k < len(all_lines):
            line_str += all_lines[i+k]
            k += 1

        line_str = line_str[0:len(key_str)+2]
        
        def sort_str(str):
            str_list = list(str)
            str_list.sort()
            return ''.join(str_list)
        radio = fuzz.token_sort_ratio(sort_str(line_str), sort_str(key_str))
        if radio > 80 and len(line_str) > 2:
            # print(str(sample_id) + '|' + key_str + ' |' + str(radio) + '|' + line_str)
            statis['fuzzy1'] += 1
            return True
        # print(str(sample_id) + '|' + key_str + ' |' + str(radio) + '|' + line_str)
    # print(str(row) + '|' + str(sample_id) + '|' + key_str + ' |' + str(radio) + '| '+str(len(key_str) - len(line_str))+'' + line_str)
    return False

def is_section_contain_table(section, table, sample_id = 0, statis = None):
    if statis == None:
        statis = collections.defaultdict(int)

    def is_empty_row(row):
        if row == None or len(row) == 0:
            return True

        empty_col = 0
        for i in row:
            if i == '':
                empty_col += 1
        
        return empty_col == len(row)

    new_table = []
    for row in table:
        if is_empty_row(row):
            continue

        new_table.append(row)

    if len(new_table) == 0:
        statis['none'] += 1
        return False

    table = new_table[:3]
    
    target = None
    for row in table:
        if target == None:
            target = row
            continue
        
        if None not in target and '' not in target:
            break

        for i in range(len(target)):
            if None == target[i]:
                target[i] = row[i]
            elif row[i] == None:
                pass
            else:
                target[i] += row[i]
    # print(table)
    # print(target)

    return is_section_contain_row(section, target, sample_id = sample_id, statis = statis)

def test_is_section_contain_table_with_train_data():
    def check_witch_data(row, statis = None):
        statis['total'] += 1
        text = row['text']
        sample_id = row['sample_id']
        # print(row['tabel'])
        table = eval(row['tabel'])

        if table == None or len(table) == 0:
            statis['none'] += 1
            return
        
        if is_section_contain_table(text, table[0], sample_id = sample_id, statis = statis):
            statis['ok'] += 1
        else:
            statis['fail'] += 1

    def nagative_check_witch_data(row, statis = None):
        table = eval(row['tabel'])
        if table == None or len(table) == 0:
            statis['none'] += 1
            return

        def check(my_row, statis = None):
            statis['total'] += 1

            if is_section_contain_table(my_row['text'], table[0], sample_id = my_row['sample_id'], statis = statis):
                statis['ok'] += 1
            else:
                statis['fail'] += 1
            
            print('\r反向结果:  总数:%d, 空table=%d, 成功=%d, 正常=%d, 【误匹配, fuzzy0=%d, fuzzy1=%d】' % \
                (statis['total'], statis['none'], statis['ok'], \
                statis['regex'], statis['fuzzy0'], statis['fuzzy1']))

        df = train_df[train_df['sample_id'] != row['sample_id']]
        df.tail(1000).apply(lambda my_row: check(my_row, statis = statis), axis=1)

    # statis = collections.defaultdict(int)
    # # train_df[train_df['sample_id'] == 2973].progress_apply(lambda row: check_witch_data(row, statis = statis), axis=1)
    # train_df.progress_apply(lambda row: check_witch_data(row, statis = statis), axis=1)
    # print('\n正向执行结果: 总数:%d, 空table=%d, 【失败=%d】, 成功=[%d], 正则=%d, fuzzy0=%d, fuzzy1=%d' % \
    #     (statis['total'], statis['none'], statis['total']-statis['fuzzy1']-statis['none'], statis['ok'],\
    #     statis['regex'], statis['fuzzy0'], statis['fuzzy1']))
    
    statis = collections.defaultdict(int)
    train_df.head(10).apply(lambda row: nagative_check_witch_data(row, statis = statis), axis=1)
    print('\n反向结果:  总数:%d, 空table=%d, 成功=%d, 正常=%d, 【误匹配, fuzzy0=%d, fuzzy1=%d】' % \
        (statis['total'], statis['none'], statis['ok'], \
        statis['regex'], statis['fuzzy0'], statis['fuzzy1']))


test_is_section_contain_table_with_train_data()
# Out:
# 反向结果:  总数:1, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:2, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:3, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:4, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:5, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:6, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:7, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:8, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:9, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:10, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:11, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:12, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:13, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:14, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:15, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:16, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:17, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:18, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:19, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:20, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:21, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:22, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:23, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:24, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:25, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:26, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:27, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:28, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:29, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:30, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:31, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:32, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:33, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:34, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:35, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:36, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:37, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:38, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:39, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:40, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:41, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:42, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:43, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:44, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:45, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:46, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:47, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:48, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:49, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:50, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:51, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:52, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:53, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:54, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:55, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:56, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:57, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:58, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:59, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:60, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:61, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:62, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:63, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:64, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:65, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:66, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:67, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:68, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:69, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:70, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:71, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:72, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:73, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:74, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:75, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:76, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:77, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:78, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:79, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:80, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:81, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:82, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:83, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:84, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:85, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:86, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:87, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:88, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:89, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:90, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:91, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:92, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:93, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:94, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:95, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:96, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:97, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:98, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:99, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:100, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:101, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:102, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:103, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:104, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:105, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:106, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:107, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:108, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:109, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:110, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:111, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:112, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:113, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:114, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:115, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:116, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:117, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:118, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:119, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:120, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:121, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:122, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:123, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:124, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:125, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:126, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:127, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:128, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:129, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:130, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:131, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:132, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:133, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:134, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:135, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:136, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:137, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:138, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:139, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:140, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:141, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:142, 空table=2, 成功=0, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=0】
# 反向结果:  总数:143, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:144, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:145, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:146, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:147, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:148, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:149, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:150, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:151, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:152, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:153, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:154, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:155, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:156, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:157, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:158, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:159, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:160, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:161, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:162, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:163, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:164, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:165, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:166, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:167, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:168, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:169, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:170, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:171, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:172, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:173, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:174, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:175, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:176, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:177, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:178, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:179, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:180, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:181, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:182, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:183, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:184, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:185, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:186, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:187, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:188, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:189, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:190, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数
 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:572, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:573, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:574, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:575, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:576, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:577, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:578, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:579, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:580, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:581, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:582, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:583, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:584, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:585, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:586, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:587, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:588, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:589, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:590, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:591, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:592, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:593, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:594, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:595, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:596, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:597, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:598, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:599, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:600, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:601, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:602, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:603, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:604, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:605, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:606, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:607, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:608, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:609, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:610, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:611, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:612, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:613, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:614, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:615, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:616, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:617, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:618, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:619, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:620, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:621, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:622, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:623, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:624, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:625, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:626, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:627, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:628, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:629, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:630, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:631, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:632, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:633, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:634, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:635, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:636, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:637, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:638, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:639, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:640, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:641, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:642, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:643, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:644, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:645, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:646, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:647, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:648, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:649, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:650, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:651, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:652, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:653, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:654, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:655, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:656, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:657, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:658, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:659, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:660, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:661, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:662, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:663, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:664, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:665, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:666, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:667, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:668, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:669, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:670, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:671, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:672, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:673, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:674, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:675, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:676, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:677, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:678, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:679, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:680, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:681, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:682, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:683, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:684, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:685, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:686, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:687, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:688, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:689, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:690, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:691, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:692, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:693, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:694, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:695, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:696, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:697, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:698, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:699, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:700, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:701, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:702, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:703, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:704, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:705, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:706, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:707, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:708, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:709, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:710, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:711, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:712, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:713, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:714, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:715, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:716, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:717, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:718, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:719, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:720, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:721, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:722, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:723, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:724, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:725, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:726, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:727, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:728, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:729, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:730, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:731, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:732, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:733, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:734, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:735, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:736, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:737, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:738, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:739, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:740, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:741, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:742, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:743, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:744, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:745, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:746, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:747, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:748, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:749, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:750, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:751, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:752, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:753, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:754, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:755, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:756, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:757, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:758, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:759, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:760, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:761, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:762, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# 反向结果:  总数:763, 空table=2, 成功=1, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=1】
# ...
# 反向结果:  总数:3045, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3046, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3047, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3048, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3049, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3050, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3051, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3052, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3053, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3054, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3055, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3056, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3057, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3058, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3059, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3060, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3061, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3062, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3063, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3064, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3065, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3066, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3067, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3068, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3069, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3070, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3071, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3072, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3073, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3074, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3075, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3076, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3077, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3078, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3079, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3080, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3081, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3082, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3083, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3084, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3085, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3086, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3087, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3088, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3089, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3090, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3091, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3092, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3093, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3094, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3095, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3096, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3097, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3098, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3099, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3100, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3101, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3102, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3103, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3104, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3105, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3106, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3107, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3108, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3109, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3110, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3111, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3112, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3113, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3114, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3115, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3116, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3117, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3118, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3119, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3120, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3121, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3122, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3123, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3124, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3125, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3126, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3127, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3128, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3129, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3130, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3131, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3132, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3133, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3134, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3135, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3136, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3137, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3138, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3139, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3140, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3141, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3142, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3143, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3144, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3145, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3146, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3147, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3148, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3149, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3150, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3151, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3152, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3153, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3154, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3155, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3156, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3157, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3158, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3159, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3160, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3161, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3162, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3163, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3164, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3165, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3166, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3167, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# 反向结果:  总数:3168, 空table=5, 成功=24, 正常=0, 【误匹配, fuzzy0=0, fuzzy1=24】
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f5f9cb884619> in <module>
#     148
#     149
# --> 150 test_is_section_contain_table_with_train_data()
#
# <ipython-input-23-f5f9cb884619> in test_is_section_contain_table_with_train_data()
#     142
#     143     statis = collections.defaultdict(int)
# --> 144     train_df.head(10).apply(lambda row: nagative_check_witch_data(row, statis = statis), axis=1)
#     145     print('\n反向结果:  总数:%d, 空table=%d, 成功=%d, 正常=%d, 【误匹配, fuzzy0=%d, fuzzy1=%d】' % \
#     146         (statis['total'], statis['none'], statis['ok'], \
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
#    7549     def applymap(self, func) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-23-f5f9cb884619> in <lambda>(row)
#     142
#     143     statis = collections.defaultdict(int)
# --> 144     train_df.head(10).apply(lambda row: nagative_check_witch_data(row, statis = statis), axis=1)
#     145     print('\n反向结果:  总数:%d, 空table=%d, 成功=%d, 正常=%d, 【误匹配, fuzzy0=%d, fuzzy1=%d】' % \
#     146         (statis['total'], statis['none'], statis['ok'], \
#
# <ipython-input-23-f5f9cb884619> in nagative_check_witch_data(row, statis)
#     132
#     133         df = train_df[train_df['sample_id'] != row['sample_id']]
# --> 134         df.tail(1000).apply(lambda my_row: check(my_row, statis = statis), axis=1)
#     135
#     136     # statis = collections.defaultdict(int)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
#    7549     def applymap(self, func) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-23-f5f9cb884619> in <lambda>(my_row)
#     132
#     133         df = train_df[train_df['sample_id'] != row['sample_id']]
# --> 134         df.tail(1000).apply(lambda my_row: check(my_row, statis = statis), axis=1)
#     135
#     136     # statis = collections.defaultdict(int)
#
# <ipython-input-23-f5f9cb884619> in check(my_row, statis)
#     122             statis['total'] += 1
#     123
# --> 124             if is_section_contain_table(my_row['text'], table[0], sample_id = my_row['sample_id'], statis = statis):
#     125                 statis['ok'] += 1
#     126             else:
#
# <ipython-input-23-f5f9cb884619> in is_section_contain_table(section, table, sample_id, statis)
#      94     # print(target)
#      95
# ---> 96     return is_section_contain_row(section, target, sample_id = sample_id, statis = statis)
#      97
#      98 def test_is_section_contain_table_with_train_data():
#
# <ipython-input-23-f5f9cb884619> in is_section_contain_row(section, row, sample_id, statis)
#      38             str_list.sort()
#      39             return ''.join(str_list)
# ---> 40         radio = fuzz.token_sort_ratio(sort_str(line_str), sort_str(key_str))
#      41         if radio > 80 and len(line_str) > 2:
#      42             # print(str(sample_id) + '|' + key_str + ' |' + str(radio) + '|' + line_str)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py in token_sort_ratio(s1, s2, force_ascii, full_process)
#     103     but sorting the token before comparing.
#     104     """
# --> 105     return _token_sort(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#     106
#     107
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py in _token_sort(s1, s2, partial, force_ascii, full_process)
#      96         return partial_ratio(sorted1, sorted2)
#      97     else:
# ---> 98         return ratio(sorted1, sorted2)
#      99
#     100
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# ~/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py in ratio(s1, s2)
#      26
#      27     m = SequenceMatcher(None, s1, s2)
# ---> 28     return utils.intr(100 * m.ratio())
#      29
#      30
#
# ~/opt/anaconda3/lib/python3.8/difflib.py in ratio(self)
#     642         """
#     643
# --> 644         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     645         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     646
#
# ~/opt/anaconda3/lib/python3.8/difflib.py in get_matching_blocks(self)
#     477         while queue:
#     478             alo, ahi, blo, bhi = queue.pop()
# --> 479             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     480             # a[alo:i] vs b[blo:j] unknown
#     481             # a[i:i+k] same as b[j:j+k]
#
# ~/opt/anaconda3/lib/python3.8/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     402             j2lenget = j2len.get
#     403             newj2len = {}
# --> 404             for j in b2j.get(a[i], nothing):
#     405                 # a[i] matches b[j]
#     406                 if j < blo:
#
# KeyboardInterrupt:

# %%
# Out:
# 0%|          | 1/7217 [00:00<05:37, 21.35it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-76958f43275e> in <module>
#      32     print('存在答案的行共有: %d' % total_ok)
#      33
# ---> 34 test_extra_possible_line()
#
# <ipython-input-33-76958f43275e> in test_extra_possible_line()
#      29
#      30 def test_extra_possible_line():
# ---> 31     total_ok = total_ok_line()
#      32     print('存在答案的行共有: %d' % total_ok)
#      33
#
# <ipython-input-33-76958f43275e> in total_ok_line()
#      25                 if line.find(a) != -1:
#      26                     statis['ok'] += 1
# ---> 27     train_df.progress_apply(lambda row: count_valid(row, answer, statis), axis=1)
#      28     return statis['ok']
#      29
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     766                 # on the df using our wrapper (which provides bar updating)
#     767                 try:
# --> 768                     return getattr(df, df_function)(wrapper, **kwargs)
#     769                 finally:
#     770                     t.close()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
#    7549     def applymap(self, func) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     761                     # take a fast or slow code path; so stop when t.total==t.n
#     762                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 763                     return func(*args, **kwargs)
#     764
#     765                 # Apply the provided function (in **kwargs)
#
# <ipython-input-33-76958f43275e> in <lambda>(row)
#      25                 if line.find(a) != -1:
#      26                     statis['ok'] += 1
# ---> 27     train_df.progress_apply(lambda row: count_valid(row, answer, statis), axis=1)
#      28     return statis['ok']
#      29
#
# <ipython-input-33-76958f43275e> in count_valid(row, answer, statis)
#      23         for line in row['text'].split('\n'):
#      24             for a in answer:
# ---> 25                 if line.find(a) != -1:
#      26                     statis['ok'] += 1
#      27     train_df.progress_apply(lambda row: count_valid(row, answer, statis), axis=1)
#
# TypeError: must be str, not int

# %% [markdown]
# #### 2.抽取实际购买公司

# %% [markdown]
# # 首先针对任务抽取时间（每个时间跟每个id是一一对应的）
# # 要不是取第一个时间，要不就是取最后一个时间（或者时间加一）这里可以建立一个模型预测
# # base这里面直接取最后一个时间作为发布日期
#
# CN_NUM = {
#     u'〇': 0, u'一': 1, u'二': 2, u'三': 3,
#     u'四': 4, u'五': 5, u'六': 6, u'七': 7,
#     u'八': 8, u'九': 9, u'零': 0, u'壹': 1,
#     u'贰': 2, u'叁': 3, u'肆': 4, u'伍': 5,
#     u'陆': 6, u'柒': 7, u'捌': 8, u'玖': 9,
#     u'貮': 2, u'两': 2,
# }
#
#
# def get_put_time_from_text(row):
#     row = row.replace(' ', '').replace('\\n', '')
#     for key in CN_NUM:
#         row = row.replace(key, str(CN_NUM[key]))
#     r = row.replace("年", "-").replace("月", "-").replace("日", " ").replace("/", "-").strip()
#     regex = "(\d{4}-\d{1,2}-\d{1,2})"
#     r = re.findall(regex, r)
#     if len(r)==0:
#         return np.nan
#     time_str = r[-1]
#     first = time_str.split('-')[0]
#     second = time_str.split('-')[1]
#     last = time_str.split('-')[-1]
#     second = str.zfill(second, 2)
#     last = str.zfill(last, 2)
#     r = '-'.join([first, second, last])
#     return r
#
# val_result = pd.DataFrame()
# val_result['sample_id'] = val_df['sample_id']
# val_result['predict_time'] = val_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)
# test_gg = train_outputs.groupby('sample_id').apply(lambda row:list(row['公告日期'])[0]).reset_index()
# test_gg.columns = ['sample_id', 'time']
# val_result = pd.merge(val_result, test_gg, on='sample_id', how='left')
#
# # 判断验证集的准确率
# np.sum(val_result['predict_time'].astype(str) == val_result['time'].astype(str))/len(val_result)
#
# val_time = val_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)
# test_time = test_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)

# %%
# 抽取购买公司
# 前几句话出现
# 将其按照\\n 和空格切割
def get_gm(row):
    result = re.split('[\\\\n ]',row)
    for i in result:
        if '公司' in i:
            return i

val_gm = val_df.progress_apply(lambda row:get_gm(row['text']), axis=1)
test_gm = test_df.progress_apply(lambda row:get_gm(row['text']), axis=1)
print(val_gm)
# Out:
# 100%|██████████| 1800/1800 [00:00<00:00, 4894.71it/s]
# 100%|██████████| 8660/8660 [00:01<00:00, 8106.25it/s]1419         成都康弘药业集团股份有限公司
# 1480    海联金汇科技股份有限公司关于三级子公司
# 5755           四川广安爱众股份有限公司
# 2446          普莱柯生物工程股份有限公司
# 5657          江苏太平洋石英股份有限公司
#                ...
# 392         上海爱婴室商务服务股份有限公司
# 177              银泰资源股份有限公司
# 2767             兴业证券股份有限公司
# 6973         烟台东诚药业集团股份有限公司
# 4840             今创集团股份有限公司
# Length: 1800, dtype: object

# %% [markdown]
# #### 3.清洗提取出来的tabel数据，主要是清洗掉有问题的列

# %%
# 将table转换格式以及处理
def deal_tabel(row):
    row = eval(row)
    if len(row)==0:
        return []
    else:
        new_row = []
        for i in row:
            for d in i:
                new_temp = []
                for h in d:
                    # 这里处理空数据或者错误的数据
                    h = str(h).replace('None', '').replace('\n','').replace(' ', '')                    
                    if h=='':
                        continue
                    if h=='.':
                        continue
                    if h=='/':
                        continue
                    new_temp.append(h)
                new_row.append(new_temp)
        # 这里判断是否构成一个完整得认购数据(通过一个list进行判断)
        new_new_row = []
        for i in new_row:
            if len(i) == 0:
                continue
            elif len(i) <= 4:
                continue
            else:
                new_new_row.append(i)
        return new_new_row

print(val_df)
train_df_tabel = train_df['tabel'].progress_apply(lambda row:deal_tabel(row))
val_df_tabel = val_df['tabel'].progress_apply(lambda row:deal_tabel(row))
test_df_tabel = test_df['tabel'].progress_apply(lambda row:deal_tabel(row))
# Out:
# 1%|▏         | 94/7217 [00:00<00:07, 897.98it/s]      sample_id                     file_path  \
# 1419       1739  datasets/train_data/1739.PDF
# 1480       1806  datasets/train_data/1806.PDF
# 5755       7032  datasets/train_data/7032.PDF
# 2446       2974  datasets/train_data/2974.PDF
# 5657       6903  datasets/train_data/6903.PDF
# ...         ...                           ...
# 392         442   datasets/train_data/442.PDF
# 177         193   datasets/train_data/193.PDF
# 2767       3359  datasets/train_data/3359.PDF
# 6973       8553  datasets/train_data/8553.PDF
# 4840       5913  datasets/train_data/5913.PDF
#
#                                                    text  \
# 1419  ['证券代码：002773                    证券简称：康弘药业    ...
# 1480  [' \n证券代码：002537              证券简称：海联金汇       ...
# 5755  ['证券代码：600979         证券简称：广安爱众     公告编号：临 201...
# 2446  [' \n证券代码：603566         证券简称： 普莱柯       公告编号：...
# 5657  ['证券代码：603688    证券简称：石英股份    公告编号：临 2017-071 ...
# ...                                                 ...
# 392   ['证券代码：603214  证券简称：爱婴室          公告编号：2018-020...
# 177   ['证券代码：000975                      证券简称：银泰资源  ...
# 2767  [' \n兴业证券股份有限公司 \n关于四川海特高新技术股份有限公司使用部分闲置募集资金及\...
# 6973  ['证券代码：002675  股票简称：东诚药业  公告编号：2018-034 \n烟台东诚...
# 4840  ['证券代码：603680         证券简称：今创集团         公告编号：2...
#
#                                                   tabel
# 1419  [[['所属银行', None, '中国银行双流安福街支行', None], ['1', '...
# 1480  [[['认\n购\n主\n体', '产\n品\n种\n类', '产品\n类型', '金额\n...
# 5755                                                 []
# 2446  [[['保本浮动收益型', '投资币种：'], ['13,500万元', '资金来源：'],...
# 5657  [[['产品名称', '华泰紫金节假日理财集合资产管\n理计划金理财 X11', '华泰紫金...
# ...                                                 ...
# 392                                                  []
# 177   [[['', '受托', '', '', None, None, '', None, Non...
# 2767  [[['序号', '投资项目', '投资预算', '自筹资金实际\n投入金额'], ['1'...
# 6973                                                 []
# 4840                                                 []
#
# [1800 rows x 4 columns]
# 100%|██████████| 7217/7217 [00:06<00:00, 1114.43it/s]
# 100%|██████████| 1800/1800 [00:01<00:00, 1311.97it/s]
# 100%|██████████| 8660/8660 [00:02<00:00, 3545.43it/s]

# %% [markdown]
# #### 4.抽取的是单独的数据包含
# #### 起息日，到息日， 金额，认购日期，产品发行方，理财产品

# %%
# 直接提取时间
# 如果出现两个时间第一个就是起息日，第二个就是到期日
# 如果出现一个时间就是起息日
# 出现的第一个money就是最后的金额
# 从这里面抽取所有序列
# 这里认为有逗号出现的就是money

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
    return False

from src.time_extractor import TimeFinder
import datetime
def get_list_data(df):
    df = list(df)
    new_df = []
    for i in tqdm(df):
        temp_df = []
        for h in i:
            new_h = []
            for digital in h:
                if ',' in digital:
                    # 这里也是为了统一数据有些是用元，有些是用万元
                    try:
                        ttt = float(digital.replace(',', '').replace('万元', '').replace('人民币', '').replace('元', ''))
                    except Exception:
                        continue
                    if ttt > 20000:
                        ttt = ttt/10000
                    new_h.append(ttt)
                else:
                    continue
            if len(new_h) == 0:
                continue
            temp_single = {}
            a = '_'.join(h)
            # 抽取时间和money
            t = TimeFinder()
            time_all = t.find_time(a)
            if time_all == None:
                continue
            rgrq = time_all[0]
            cpqxr = time_all[0]
            if len(time_all) > 1:
                try:
                    cpdxr = time_all[1]
                    # 相减
                    d1 = datetime.datetime.strptime(cpqxr, '%Y-%m-%d')
                    d2 = datetime.datetime.strptime(cpdxr, '%Y-%m-%d')
                    d = d2 - d1
                    cpqx = str(d.days) + '天'
                except Exception:
                    cpdxr = np.nan
                    cpqx = np.nan
            else:
                cpdxr = np.nan
                cpqx = np.nan
                
            # 筛选出除开数字与包含时间的列
            # 末尾是
            last_two = ['公司', '银行', '信托', '证券',  '分行', '支行', '中心', '业部', '商行', '建行']
            mowei = np.nan
            selected_bank_and_works = []
            for l in h:
                new_l = list(str(l))
                new_l_test = ''.join(l[-2:])
                if new_l_test in last_two:
                    mowei = l
                    continue
                if '资金' in l:
                    continue
                if '收益' in l:
                    continue
                if '到期' in l:
                    continue
                if ',' in l:
                    continue
                if '.' in l:
                    continue
                if '/' in l:
                    continue
                if '年' in l:
                    continue
                if '-' in l:
                    continue
                if len(l) < 4:
                    continue
                if is_number(l):
                    continue
                selected_bank_and_works.append(l)
            if len(selected_bank_and_works) < 1:
                continue
            
            temp_single['认购日期'] = rgrq
            temp_single['产品起息日'] = cpqxr
            temp_single['产品到期日'] = cpdxr
            temp_single['产品期限'] = cpqx
            temp_single['认购金额(万元)'] = new_h[0]
            temp_single['产品发行方名称'] = mowei
            temp_single['理财产品名称'] = selected_bank_and_works[0]
            temp_df.append(temp_single)
        new_df.append(temp_df)
    return new_df

val_contain_date = get_list_data(val_df_tabel)
test_contain_data = get_list_data(test_df_tabel)
# Out:
# 100%|██████████| 1800/1800 [05:09<00:00,  5.81it/s]
#  56%|█████▌    | 4863/8660 [07:37<05:57, 10.63it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-a502b37fada1> in <module>
#     115
#     116 val_contain_date = get_list_data(val_df_tabel)
# --> 117 test_contain_data = get_list_data(test_df_tabel)
#
# <ipython-input-33-a502b37fada1> in get_list_data(df)
#      48             # 抽取时间和money
#      49             t = TimeFinder()
# ---> 50             time_all = t.find_time(a)
#      51             if time_all == None:
#      52                 continue
#
# ~/Source/baseline_qqcywdj/src/time_extractor.py in find_time(self, text)
#      79             for item in self.match_item:
#      80                 try:
# ---> 81                     date = datetime.strptime(match,item[1].replace('\\',''))
#      82                     if date.year==1900:
#      83                         date = date.replace(year=self.base_date.year)
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in _strptime(data_string, format)
#     331         if not format_regex:
#     332             try:
# --> 333                 format_regex = _TimeRE_cache.compile(format)
#     334             # KeyError raised when a bad format is found; can be specified as
#     335             # \\, in which case it was a stray % but with a space after it
#
# ~/opt/anaconda3/lib/python3.8/_strptime.py in compile(self, format)
#     261     def compile(self, format):
#     262         """Return a compiled re object for the format string."""
# --> 263         return re_compile(self.pattern(format), IGNORECASE)
#     264
#     265 _cache_lock = _thread_allocate_lock()
#
# ~/opt/anaconda3/lib/python3.8/re.py in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#     253
#     254 def purge():
#
# ~/opt/anaconda3/lib/python3.8/re.py in _compile(pattern, flags)
#     290     # internal: compile pattern
#     291     if isinstance(flags, RegexFlag):
# --> 292         flags = flags.value
#     293     try:
#     294         return _cache[type(pattern), pattern, flags]
#
# ~/opt/anaconda3/lib/python3.8/types.py in __get__(self, instance, ownerclass)
#     169         self.__isabstractmethod__ = bool(getattr(fget, '__isabstractmethod__', False))
#     170
# --> 171     def __get__(self, instance, ownerclass=None):
#     172         if instance is None:
#     173             if self.__isabstractmethod__:
#
# KeyboardInterrupt:

# %% [markdown]
# #### 5.汇总整理数据

# %%
# 将前面提取到的数据整理成对应格式
sample_id_list = []
rgrq_list = []
lccp_list = []
cpfxf_list = []
rgje_list = []
cpqxr_list = []
cpdxr_list = []
cpqx_list = []
sjgmgsmc_list = []
ggrq_list = []

sample_id = list(val_df['sample_id'])
gg = list(val_gm)
time = list(val_time)
for i, value in enumerate(sample_id):
    for j in val_contain_date[i]:
        sample_id_list.append(sample_id[i])
        rgrq_list.append(j['认购日期'])
        lccp_list.append(j['理财产品名称'])
        cpfxf_list.append(j['产品发行方名称'])
        rgje_list.append(j['认购金额(万元)'])
        cpqxr_list.append(j['产品起息日'])
        cpdxr_list.append(j['产品到期日'])
        cpqx_list.append(j['产品期限'])
        sjgmgsmc_list.append(gg[i])
        ggrq_list.append(time[i])

result = pd.DataFrame()
result['sample_id'] = sample_id_list
result['认购日期'] = rgrq_list
result['理财产品名称'] = lccp_list
result['产品发行方名称'] = cpfxf_list
result['认购金额(万元)'] = rgje_list
result['产品起息日'] = cpqxr_list
result['产品到期日'] = cpdxr_list
result['产品期限'] = cpqx_list
result['实际购买公司名称'] = sjgmgsmc_list
result['公告日期'] = ggrq_list
val_result = result

# %%
sample_id_list = []
rgrq_list = []
lccp_list = []
cpfxf_list = []
rgje_list = []
cpqxr_list = []
cpdxr_list = []
cpqx_list = []
sjgmgsmc_list = []
ggrq_list = []

sample_id = list(test_df['sample_id'])
gg = list(test_gm)
time = list(test_time)
for i, value in enumerate(sample_id):
    for j in test_contain_data[i]:
        sample_id_list.append(sample_id[i])
        rgrq_list.append(j['认购日期'])
        lccp_list.append(j['理财产品名称'])
        cpfxf_list.append(j['产品发行方名称'])
        rgje_list.append(j['认购金额(万元)'])
        cpqxr_list.append(j['产品起息日'])
        cpdxr_list.append(j['产品到期日'])
        cpqx_list.append(j['产品期限'])
        sjgmgsmc_list.append(gg[i])
        ggrq_list.append(time[i])

result = pd.DataFrame()
result['sample_id'] = sample_id_list
result['认购日期'] = rgrq_list
result['理财产品名称'] = lccp_list
result['产品发行方名称'] = cpfxf_list
result['认购金额(万元)'] = rgje_list
result['产品起息日'] = cpqxr_list
result['产品到期日'] = cpdxr_list
result['产品期限'] = cpqx_list
result['实际购买公司名称'] = sjgmgsmc_list
result['公告日期'] = ggrq_list
test_result = result
test_result
