# %% [markdown]
# # 导入相关包

# %%
# 导入相关包
import os
import pathlib as pl
import pandas as pd
import numpy as np
import re
from io import StringIO
from datetime import datetime 
import time
from IPython.core.interactiveshell import InteractiveShell
from tqdm.autonotebook import *
import pdfplumber
tqdm.pandas()
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# def extract_pdf_content(pdf_path):
#     text_list = []
#     table_list = []
#     with pdfplumber.open(pdf_path) as pdf:
#         for index_page in np.arange(0, len(pdf.pages), 1):
#             # 读取多页
#             page = pdf.pages[index_page]   # 第n页的信息
#             text = page.extract_text()
#             text_list.append(text)
#             table = page.extract_tables()
#             for t in table:
#                 table_list.append(t)
#     return text_list, table_list
#
# # a='train_output'
# # b="train"+r"_\d"
# # print(re.match(b,a))
# def csv_2_df(file_path):
#     file_list=file_path.parents[0].glob("*.csv")
#     result=None
#     for item in file_list:
#         if re.match(file_path.stem.split("_")[0]+r"_\d",item.stem) is not None:
#             print(item.name)
#             result=pd.read_csv(item) if result is None else pd.concat([result,pd.read_csv(item)])
#     return result
#
# test_path = pl.Path('datasets/train_1.csv')
#
# test_df = csv_2_df(test_path)
# test_df.to_csv("datasets/train.csv",index=None)

# %% [markdown]
# # PDF解析原始数据
# ## 加载数据并采用pdfplumber抽取PDF中的文字和表格

# %%
# 数据准备(train_output文件中格式有点问题，需要提前用excel或者wps打开然后另存为excel文件)
train_outputs = pd.read_excel('datasets/train_output.xlsx')

# 获取pdf中文字和表格
def extract_pdf_content(pdf_path):
    text_list = []
    table_list = []
    with pdfplumber.open(pdf_path) as pdf:
        for index_page in np.arange(0, len(pdf.pages), 1):
            # 读取多页
            page = pdf.pages[index_page]   # 第n页的信息
            text = page.extract_text()
            text_list.append(text)
            table = page.extract_tables()
            for t in table:
                table_list.append(t)
    return text_list, table_list

def get_dir_file(path):
    '''
    输入文件夹位置，输出整理好的dataframe
    '''
    path_list = os.listdir(path)
    id_list = []
    file_path_list = []
    text_list = []
    table_list = []
    for i in tqdm(path_list):
        if '.PDF' in i:
            file_path = path + i
            id_list.append(int(i.split('.')[0]))
            file_path_list.append(file_path)
            try:
                text_temp, table_temp = extract_pdf_content(file_path)
            except Exception:
                print('此pdf无法读取')
                text_temp, table_temp = [], []
            text_list.append(text_temp)
            table_list.append(table_temp)
            
    df = pd.DataFrame()
    df['sample_id'] = id_list
    df['file_path'] = file_path_list
    df['text'] = text_list
    df['tabel'] = table_list
    df = df.sort_values('sample_id')
    return df

# 文件处理太慢，可持续化保存文件
train_path = 'datasets/train.csv'
if os.path.exists(train_path):
    train_df = pd.read_csv(train_path)
else:
    train_df = get_dir_file('datasets/train_data/')
    train_df.to_csv(train_path,index=False)
    train_df = pd.read_csv(train_path)

test_path =  'datasets/test.csv'
if os.path.exists(test_path):
    test_df = pd.read_csv(test_path)
else:
    test_df = get_dir_file('datasets/test_data/')
    test_df.to_csv(test_path,index=False)
    test_df = pd.read_csv(test_path)

train_outputs.head(2)
train_df.head(2)
test_df.head(2)
# Out:
#    sample_id       认购日期        理财产品名称     产品发行方名称    理财类型  认购金额(万元)  \
# 0          1 2019-03-27         汇聚金1号  中融国际信托有限公司      信托   10000.0
# 1          1 2019-03-27  招商银行步步生金8699        招商银行  银行理财产品     200.0
#
#        产品起息日      产品到息日  产品期限  资金来源    实际购买公司名称 实际购买公司和上市公司关系 买卖方是否有关联关系  \
# 0 2019-03-27 2019-09-23  180天  自有资金  恒生电子股份有限公司          公司本身          否
# 1 2019-03-27        NaT   NaN  自有资金  恒生电子股份有限公司          公司本身          否
#
#         公告日期
# 0 2019-04-25
# 1 2019-04-25
#    sample_id                  file_path  \
# 0          1  datasets/train_data/1.PDF
# 1          2  datasets/train_data/2.PDF
#
#                                                 text  \
# 0  ['                                            ...
# 1  ['                                            ...
#
#                                                tabel
# 0  [[['', None, None, '', None, None, '', None, N...
# 1  [[['', None, None, '', None, None, '', None, N...
#    sample_id                     file_path  \
# 0      11188  datasets/test_data/11188.PDF
# 1      11189  datasets/test_data/11189.PDF
#
#                                                 text tabel
# 0  ['北京京西文化旅游股份有限公司监事会\n \n \n关于使用部分闲置募集资金购买理财产品的...    []
# 1  ['北京京西文化旅游股份有限公司 \n监事会关于使用部分自有资金购买理财产品的意见 \n根据...    []

# %%
# 构造训练集验证集
train_df = train_df.sample(frac=1, random_state=1017)
val_df = train_df[:1800]
train_df = train_df[1800:]

# %% [markdown]
# # 数据处理
# ## 抽取整体数据（一个sampleid内此字段内容都相同）
# ## 公告时间，实际购买公司

# %% [markdown]
# #### 1.抽取公告时间

# %%
# 首先针对任务抽取时间（每个时间跟每个id是一一对应的）
# 要不是取第一个时间，要不就是取最后一个时间（或者时间加一）这里可以建立一个模型预测
# base这里面直接取最后一个时间作为发布日期

##wjc字典里添加了十
CN_NUM = {
    u'月十日':'月10日',u'十月':'10月', u'十日': '0日',u'二十':'二',u'三十':'三', u'十': 1, u'○': 0, u'O':'0', u'Ο':'0',
    u'〇': 0, u'一': 1, u'二': 2, u'三': 3,
    u'四': 4, u'五': 5, u'六': 6, u'七': 7,
    u'八': 8, u'九': 9, u'零': 0, u'壹': 1,
    u'贰': 2, u'叁': 3, u'肆': 4, u'伍': 5,
    u'陆': 6, u'柒': 7, u'捌': 8, u'玖': 9,
    u'貮': 2, u'两': 2,  
}
######### u'○': 0, u'O':'0', u'Ο':'0',##########可删除这些字典，改用添加内容效果一致，这里暂且保留字典


def get_put_time_from_text(row):
    row = row.replace(' ', '').replace('\\n', '')

    ############添加#################改善年份中0有多个不识别的问题########
    start=1
    for word in '一二三四五六七八九':   
        row=re.sub('二.一'+word,'201'+str(start),row)
        start=start+1
    ########添加############慢#######################

    for key in CN_NUM:
        row = row.replace(key, str(CN_NUM[key]))   

    r = row.replace("年", "-").replace("月", "-").replace("日", " ").replace("/", "-").strip()
    regex = "(\d{4}-\d{1,2}-\d{1,2})"
    r = re.findall(regex, r)
    if len(r)==0:
        return np.nan
    time_str = r[-1]
    first = time_str.split('-')[0]
    second = time_str.split('-')[1]
    last = time_str.split('-')[-1]
    second = str.zfill(second, 2)
    last = str.zfill(last, 2)
    r = '-'.join([first, second, last])
    return r




val_result = pd.DataFrame()
val_result['sample_id'] = val_df['sample_id']
val_result['predict_time'] = val_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)
test_gg = train_outputs.groupby('sample_id').apply(lambda row:list(row['公告日期'])[0]).reset_index()
test_gg.columns = ['sample_id', 'time']
val_result = pd.merge(val_result, test_gg, on='sample_id', how='left')
##val_result['time'].head(10)
###val_result['predict_time'].head(10)

np.set_printoptions(threshold=np.inf)
pd.set_option('max_colwidth',100)

testid=6375
print(train_df[train_df.sample_id==testid]['text'].astype(str))
print(val_df[val_df.sample_id==testid]['text'].astype(str))


# 对于每一行，通过列名name访问对应的元素
for index,row in val_result.iterrows():
    #type(row['predict_time'])
    #print(row['sample_id'],row['predict_time']) # 输出每一行
    try:
        val_result.at[index,'predict_time1']=datetime.strptime(row['predict_time'], "%Y-%m-%d").strftime('%Y/%m/%d')
        #val_result.at[index,'predict_time1']=time.strptime(row['predict_time'], "%Y-%m-%d")
    except:
        #val_result.at[index,'predict_time1']='1900/01/01'
        continue
        # print(row['sample_id'])
        # print(val_df[val_df.sample_id==row['sample_id']]['text'].astype(str))
        
for index,row in val_result.iterrows():
    val_result.at[index,'time1']=val_result.at[index,'time'].strftime("%Y-%m-%d %H:%M:%S")[0:10]
    val_result.at[index,'time2']=val_result.at[index,'time1'].replace('-','')
    try:
        val_result.at[index,'predict_time2']=val_result.at[index,'predict_time'].replace('-','')
    except:
        continue
    #######粗计算时间具体误差################
    val_result.at[index,'差值']=(int)(val_result.at[index,'predict_time2'])-(int)(val_result.at[index,'time2'])

fail_val_result=val_result[val_result['差值']!=0]
#######抽取错误列放入fail的dataframe########################


# val_result['predict_time_inf']=pd.to_datetime(val_result['predict_time'],format='%Y/%m/%d')
# val_result['predict_time_inf'].head(10)

#val_result['predict_time1'] = datetime.strptime(val_result['predict_time'], "%Y-%m-%d").strftime('%Y/%m/%d')
#val_result['predict_time_inf']=pd.to_datetime(val_result['predict_time1'],format='%Y/%m/%d')
#val_result['日期差值']=val_result['predict_time_inf']-val_result['time']
#val_result.head(10)

# 判断验证集的准确率
np.sum(val_result['predict_time'].astype(str) == val_result['time'].astype(str))/len(val_result)

# val_time = val_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)
# test_time = test_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)

val_time=pd.DataFrame()
val_time["公告日期"]=val_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)
# val_gm = val_df.progress_apply(lambda row:my_get_gm(row['text']), axis=1)
val_time['sample_id'] = val_df['sample_id']
#test_gm = test_df.progress_apply(lambda row:get_gm(row['text']), axis=1)

test_time=pd.DataFrame()
test_time["公告日期"]=test_df.progress_apply(lambda row: get_put_time_from_text(row['text']), axis=1)
# val_gm = val_df.progress_apply(lambda row:my_get_gm(row['text']), axis=1)
test_time['sample_id'] = test_df['sample_id']
#test_gm = test_df.progress_apply(lambda row:get_gm(row['text']), axis=1)
# Out:
# 100%|██████████| 1800/1800 [00:00<00:00, 3080.02it/s]
# Series([], Name: text, dtype: object)
# 5162    [None]
# Name: text, dtype: object
# 0.5883333333333334
# 100%|██████████| 1800/1800 [00:00<00:00, 3478.38it/s]
# 100%|██████████| 8660/8660 [00:02<00:00, 3871.79it/s]

# %% [markdown]
# #### 2.抽取实际购买公司

# %%
# 抽取购买公司
# 前几句话出现
# 将其按照\\n 和空格切割
def get_gm(row):
    row=row.replace('[','').replace(']','').replace('\'','')    ######粗datawash,去除部分典型符号###########
    #head_row=re.split('资金',row)[0]
    #head_row=re.split('使用',head_row)[0]
    #tag_head_row=headrow.replace('[\\\\n ]','$|$')
    result = re.split('[\\\\n ]',row)
    for i in result:
        if '公司' in i:
            i=i.replace('（','(').replace('）',')') ##########修改中文括号#################
            regex="(^.*公司)"##################此四行为添加的##############################
            i=re.findall(regex, i)###########取此行最后一个“公司”前的字符#######
            i=i[0]###############格式转换，list取出str####################################
            if i=='公司':
                continue   ###########跳过字段为公司的答案进入下一个循环#####################
            return i




########################粗改进######################################
def my_get_gm(row):
    row=row.replace('[','').replace(']','').replace('\'','')    ######粗datawash,去除部分典型符号###########
    re_row = re.split('[\\\\n ]',row)
    
    ##################取第一次出现公司的行开始计算###################
    for i in re_row:
        if '公司' not in i:
            re_row.remove(i)
        else:
            break
    
    head_row=""
    #################list替换为文本##########################
    for i in re_row:
        head_row=head_row+i+'$|$'
    
    

    # print(type(head_row.find("公告编号")))
    # head_row=head_row[head_row.find("公告编号"):-1]

    # head_row=head_row.split("^.*公告编号：")[0]
    # head_row_a=head_row.split("资金")[0]
    # head_row=head_row_a.split("使用")[0]
    # head_row=head_row_a.split("委托")[0]
    # head_row=head_row_a.split("董事")[0]
    head_row=head_row.split("理财")[0].split("资金")[0].split("使用")[0].split("董事")[0]
    # print(head_row_a)
    tag_head_row=head_row.replace(' ','').replace('子公司','$|$').replace('公司','公司$|$').replace('关于','$|$').replace('-','$|$')
    # spl_head_row = re.split('\$\|\$',tag_head_row)
    spl_head_row = tag_head_row.split('$|$')
    spl_head_row.reverse()
    result=spl_head_row
    for i in result:
        if '公司' in i:
            i=i.replace('（','(').replace('）',')') ##########修改中文括号#################
            regex="(^.*公司)"##################此四行为添加的##############################
            i=re.findall(regex, i)###########取此行最后一个“公司”前的字符#######
            i=i[0]###############格式转换，list取出str####################################
            if i=='公司' or len(i)<=4 or '”' in i or '“' in i or '简称' in i:
                continue   ###########跳过字段为公司的答案进入下一个循环#####################
            return i
#################到此为止####################################




########################二次改进,文本内容查找追加，成功率暂时比不追加要低一点######################################
def my_get_gm2(row):
    row=row.replace('[','').replace(']','').replace('\'','')    ######粗datawash,去除部分典型符号###########
    re_row = re.split('[\\\\n ]',row)
    
    ###################取第一次出现公司的行开始计算###################
    for i in re_row:
        if '公司' not in i:
            re_row.remove(i)
        else:
            break
    
    
    head_row=""
    #################list替换为文本##########################
    for i in re_row:
        head_row=head_row+i+'$|$'
    
    #################去除标题#############################
    text_row1=head_row[head_row.find("公告"):-1]
    text_row2=head_row[head_row.find("意见"):-1]
    regex = "(子公司.*公司.*购买)"
    text1 = re.findall(regex, text_row1)
    text2 = re.findall(regex, text_row2)
    text=text1+text2
    for i in text:
        if '$|$' in i:
            text.remove(i)
    my_list=[]
    for i in text:
        spl_i=i.replace("购买","$|$").replace("子公司","$|$").replace("公司","公司$|$")
        spl_i=spl_i.split("$|$")
        spl_i.reverse()
        for j in spl_i:
            if '公司' in j:
                j=j.replace('（','(').replace('）',')')
                regex="(^.*公司)"
                j=re.findall(regex, j)
                j=j[0]
                if j=='公司' or len(j)<=4 or len(j)>30 or '”' in j or '“' in j or '简称' in j:
                    continue
                my_list.append(j)
    #print(text1)

    
    
    head_row=head_row.split("理财")[0].split("资金")[0].split("使用")[0].split("董事")[0]
    # print(head_row_a)
    tag_head_row=head_row.replace(' ','').replace('子公司','$|$').replace('公司','公司$|$').replace('关于','$|$').replace('-','$|$')
    # spl_head_row = re.split('\$\|\$',tag_head_row)
    spl_head_row = tag_head_row.split('$|$')
    spl_head_row.reverse()
    result=spl_head_row
    for i in result:
        if '公司' in i:
            i=i.replace('（','(').replace('）',')') ##########修改中文括号#################
            regex="(^.*公司)"##################此四行为添加的##############################
            i=re.findall(regex, i)###########取此行最后一个“公司”前的字符#######
            i=i[0]###############格式转换，list取出str####################################
            if i=='公司' or len(i)<=4 or '”' in i or '“' in i or '简称' in i:
                continue   ###########跳过字段为公司的答案进入下一个循环#####################
            my_list.insert(0,i)
            i=my_list[-1]
            return i
#################到此为止####################################





###val_gm = val_df.progress_apply(lambda row:get_gm(row['text']), axis=1)
val_gm=pd.DataFrame()
val_gm["实际购买公司名称"]=val_df.progress_apply(lambda row:my_get_gm(row['text']), axis=1)
# val_gm = val_df.progress_apply(lambda row:my_get_gm(row['text']), axis=1)
val_gm['sample_id'] = val_df['sample_id']
#test_gm = test_df.progress_apply(lambda row:get_gm(row['text']), axis=1)

test_gm=pd.DataFrame()
test_gm["实际购买公司名称"] = test_df.progress_apply(lambda row:my_get_gm(row['text']), axis=1)
test_gm['sample_id']=test_df['sample_id']


my_val_result = pd.DataFrame()
my_val_result['sample_id'] = val_df['sample_id']
my_val_result['predict_gs'] = val_df.progress_apply(lambda row: my_get_gm(row['text']), axis=1)
my_test_gs = train_outputs.groupby('sample_id').apply(lambda row:list(row['实际购买公司名称'])[0]).reset_index()
my_test_gs.columns = ['sample_id', 'gs']
my_val_result = pd.merge(my_val_result, my_test_gs, on='sample_id', how='left')
my_val_result['是否相等']=my_val_result['predict_gs']==my_val_result['gs']
fail_my_val_result=my_val_result[my_val_result['是否相等']!=True]


np.set_printoptions(threshold=np.inf)
pd.set_option('max_colwidth',100)

testid=3597
print(train_df[train_df.sample_id==testid]['text'].astype(str))
print(val_df[val_df.sample_id==testid]['text'].astype(str))

# 判断验证集的准确率
np.sum(my_val_result['predict_gs'].astype(str) == my_val_result['gs'].astype(str))/len(my_val_result)
# Out:
# 100%|██████████| 1800/1800 [00:02<00:00, 851.94it/s]
# 100%|██████████| 8660/8660 [00:05<00:00, 1709.84it/s]
# 100%|██████████| 1800/1800 [00:02<00:00, 858.43it/s]
# Series([], Name: text, dtype: object)
# 2929    [None, None, None, None, None]
# Name: text, dtype: object
# 0.7972222222222223

# %% [markdown]
# 文章段落初步分段

# %%
def get_title(text):
    global title_num_char
    title_list=[]
    title_type_list=[]
    text_start_iter_list=[]
    text_end_iter_list=[]
    for item in title_num_char:
        pattern = re.compile(item+r"[ ]*?[^ ]+?[ ]")
        tmp=pattern.finditer(text)
        for i in tmp:
            title_list.append(i.group())
            text_start_iter_list.append(i.span(0)[0])
            title_type_list.append(1)
            text_end_iter_list.append(i.span(0)[1])
    
    # for item in title_list:
    for item in s_title_num_char:
        pattern = re.compile(item+r"[ ]*?[^ ]+?[ ]")
        tmp=pattern.finditer(text)
        for i in tmp:
            title_list.append(i.group())
            text_start_iter_list.append(i.span(0)[0])
            title_type_list.append(2)
            text_end_iter_list.append(i.span(0)[1])

    title_list.append("引言")
    title_type_list.append(1)
    text_start_iter_list.append(0)
    text_end_iter_list.append(0)

    result_df=pd.DataFrame([title_list,title_type_list,text_start_iter_list,text_end_iter_list]).T.sort_values(by=2).reset_index(drop=True)
    # print(result_df)
    return result_df

def get_title_text(text,title_df):
    # print(title_df)
    title_1_df=title_df[title_df[1]==1]
    text_iter_list=[]
    text_list=[]
    # print(title_1_df)
    for iter1,iter2 in title_1_df[[2,3]].values:
        # print(iter1)
        if(len(text_iter_list)!=0):
            text_iter_list.append(iter1)
        text_iter_list.append(iter2)
    # text_iter_list.append(text_iter_list[len(text_iter_list)-1])
    text_iter_list.append(len(text))
    for index in range(int(len(text_iter_list)/2)):
        text_list.append(text[text_iter_list[2*index]:text_iter_list[2*index+1]])
    
    title_1_df[4]=text_list

    return title_1_df.reset_index(drop=True)

from fuzzywuzzy import fuzz
def judge_title(sample_id=0,text=r"test\n"):
    # print(text)
    text=text.replace(r"\n","")
    title_df=get_title(text)
    title_df["sample_id"]=[sample_id for x in range(title_df.shape[0])]
    # print(title_df)
    title_1_df=get_title_text(text,title_df)[["sample_id",0,1,2,3,4]]

    

    global val_df
    global train_outputs
    val_true_name=train_outputs[train_outputs["sample_id"]==sample_id]["理财产品名称"]
    
    index=0
    neg_index=[]
    for title_des in title_1_df[0].values:
        for item in title_neg_words:
            if re.search(item,title_des) is not None:
                neg_index.append(index)
                break
        index+=1


    return title_1_df.drop(neg_index)
    # print(title_list)

def get_judge_title_result(val_df):

    judge_title_result=None


    for sample_id,text in tqdm(val_df[["sample_id","text"]].values):
        # print(sample_id)
        # print(text)
        judge_title_result= judge_title(sample_id,text) if judge_title_result is None else pd.concat([judge_title_result,judge_title(sample_id,text)])
    
    return judge_title_result

title_num_char=["一、","二、","三、","四、","五、","六、","七、","八、","九、","十、","十一、","十二、","十三、","十四、","十五、"]
s_title_num_char=["（一）","（二）","（三）","（四）","（五）","（六）","（七）","（八）","（九）","（十）","（十一）","（十二）","（十三）","（十四）","（十五）"]
s_title_num_char.extend(["[(]一[)]","[(]二[)]","[(]三[)]","[(]四[)]","[(]五[)]","[(]六[)]","[(]七[)]","[(]八[)]","[(]九[)]","[(]十[)]","[(]十一[)]","[(]十二[)]","[(]十三[)]","[(]十四[)]","[(]十五[)]"])

title_pos_words=[]
title_neg_words=["备查","日前","过去","履行","审批","程序","风险","措施","影响","累计","赎回","到期","截至","意见","十二个月内","公告前","报备文件","前期"]
val_judge_title_result=get_judge_title_result(val_df)
test_judge_title_result=get_judge_title_result(test_df)
# judge_title_result.to_excel("训练集段落标题分类结果.xlsx",index=None)
# Out:
# 100%|██████████| 1800/1800 [00:19<00:00, 91.55it/s]
# 100%|██████████| 8660/8660 [01:45<00:00, 82.27it/s]

# %%
# 最后一部分字段采用预测好的部分，跟提取的text做交互采用双输入lstm在dense层做交互预测最后几个字段

# train_lstm_input = pd.merge(train_df, train_outputs, on='sample_id', how='left')
# result_matrix
from tgrocery import Grocery
train_lstm_input = pd.merge(train_df, train_outputs, on='sample_id', how='left')

train_lstm_input = train_lstm_input.fillna('否')

# label_1理财类型-10  label_2资金来源-3 label_3实际购买公司和上市公司关系-3 label_4买卖方是否有关联关系-2
from sklearn.preprocessing import LabelEncoder
label_1 = LabelEncoder()
# label_2 = LabelEncoder()
# label_3 = LabelEncoder()
# label_4 = LabelEncoder()

train_data = pd.DataFrame()
tmp=pd.DataFrame()
train_data['text_1'] = train_lstm_input['理财产品名称'].astype(str) 

# train_data['text_1'] = train_lstm_input['理财产品名称'].astype(str) + '_' + train_lstm_input['产品发行方名称'].astype(str)

# train_data['text_2'] = train_lstm_input['text'].astype(str)

# train_lstm_input["文本类别"]="理财产品"

train_data['label_1'] = "理财产品"


train_data2=train_lstm_input[train_lstm_input["产品发行方名称"]!="否"].reset_index(drop=True)

# train_data2["文本类别"]="发行方"

tmp['text_1']=train_data2["产品发行方名称"].astype(str)

# tmp['text_2']= train_data2["text"].astype(str)

tmp['label_1']="发行方"

train_data = pd.concat([train_data,tmp]).reset_index(drop=True)

# train_data2=train_lstm_input[train_lstm_input["实际购买公司名称"]!="否"].reset_index(drop=True)

# # train_data2["文本类别"]="发行方"

# tmp['text_1']=train_data2["实际购买公司名称"].astype(str)

# # tmp['text_2']= train_data2["text"].astype(str)

# tmp['label_1']="购买公司"

# train_data = pd.concat([train_data,tmp]).reset_index(drop=True)


other_columns_list=["认购金额(万元)","认购日期","资金来源","实际购买公司和上市公司关系","实际购买公司名称"]

for item in other_columns_list:

    train_data2=train_lstm_input[train_lstm_input[item]!="否"].reset_index(drop=True)

    # train_data2["文本类别"]=item

    tmp['text_1']=train_data2[item].astype(str)

    # tmp['text_2']= train_data2["text"].astype(str)

    tmp['label_1']="其它"

    
    train_data = pd.concat([train_data,tmp]).reset_index(drop=True)



# train_data['label_2'] = label_2.fit_transform(train_lstm_input['资金来源'])
# train_data['label_3'] = label_3.fit_transform(train_lstm_input['实际购买公司和上市公司关系'])
# train_data['label_4'] = label_4.fit_transform(train_lstm_input['买卖方是否有关联关系'])
train_data

train_src=[]
for text,label in train_data[["text_1","label_1"]].values:
    train_src.append([label,text])


grocery=Grocery("productOrcounter")


grocery.train(train_src)

grocery.save()
# Out:
#                               text_1 label_1
# 0                 中银保本理财-人民币按期开放理财产品    理财产品
# 1                 中银保本理财-人民币按期开放理财产品    理财产品
# 2                        与利率挂钩的结构性产品    理财产品
# 3             广发银行“薪加薪”16号XJXCKJ2578    理财产品
# 4       兴业银行“金雪球-优悦”保本开放式人民币理财产品(2M)    理财产品
# ...                              ...     ...
# 185903                  上海浦兴投资发展有限公司      其它
# 185904                  上海浦兴投资发展有限公司      其它
# 185905                  上海浦兴投资发展有限公司      其它
# 185906                  上海浦兴投资发展有限公司      其它
# 185907             上海市浦东新区建设(集团)有限公司      其它
#
# [185908 rows x 2 columns]
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\lsqlh\AppData\Local\Temp\jieba.cache
# Loading model cost 0.939 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# #### 3.清洗提取出来的tabel数据，主要是清洗掉有问题的列

# %%
# tabel_tmp_value=eval(val_df[val_df["sample_id"]==4333]["tabel"].iloc[0])
# tabel_tmp_value=eval(val_df[val_df["sample_id"]==35]["tabel"].iloc[0])
# tabel_tmp_value_list=[]
# table_value_df=pd.DataFrame(tabel_tmp_value[0])
# table_value_df.head(20)
# for item in tabel_tmp_value:

column_name_judge_word=["民币）","民币)","万元)","元)","万元）","元）","%)","%）","金额"]


#寻找有有效值存在的列
def find_valid_columns(df):
    count_list=[]
    result=[]
    df.copy().T.apply(lambda x:count_list.append(get_valid_columns_num(x.T)),axis=1)
    # df.copy().T.apply(lambda x:print(x),axis=1)
    # print(count_list)
    # print(count_list)
    for i in range(len(count_list)):
        if count_list[i]>(int(df.shape[0]/7)):
            result.append(i)
    # print(result)   
    return result


#寻找（字段）所在的理论最后一行
def find_amt(df):
    global column_name_judge_word
    max_index=-1
    df=df.head(7)
    for index in range(df.shape[0]):
        for item in column_name_judge_word:
            flag=[]
            flag_num=[]
            df.loc[index].map(lambda x:flag_num.append(re.match("[ ]*?\d",x)))
            df.loc[index].map(lambda x:flag.append((item in x)))
            for i in flag_num:
                if(i is not None):
                    return max_index
            if True in flag:
                max_index=index
    return max_index

column_name_judge_word=["民币）","民币)","万元)","元)","万元）","元）","%)","%）","金额"]


#寻找单个理财产品所在的理论最后一行
def find_product(df):
    global column_name_judge_word
    max_index=-1
    df=df.head(7)
    for index in range(df.shape[0]):
        for item in column_name_judge_word:
            flag=[]
            flag_num=[]
            df.loc[index].map(lambda x:flag_num.append(re.match("[ ]*?\d",x)))
            df.loc[index].map(lambda x:flag.append((item in x)))
            for i in flag_num:
                if(i is not None):
                    return max_index
            if True in flag:
                max_index=index
    return max_index

def get_valid_columns_num(df):
    df=df.T.dropna(axis=0).apply(lambda x:x.replace(" ","")).to_frame().T.reset_index(drop=True).T
    # print(df)
    return df[(df[0]!="")&(df[0]!=np.nan)].shape[0]

def get_valid_columns_index(df):
    df=df.T.dropna(axis=0).apply(lambda x:x.replace(" ","")).to_frame().T.reset_index(drop=True).T
    # print(df)
    return df[(df[0]!="")&(df[0]!=np.nan)].index

def field_location_optimization(columns_list,df):
    if(df.shape[1]!=columns_list.shape[0]):
        return columns_list.to_frame().T.head(0)
    max_columns_num=get_valid_columns_num(columns_list)
    if(df.shape[0]==0):
        return df
    valid_clomuns_index=list(get_valid_columns_index(columns_list))
    # print(valid_clomuns_index)
    result_df=df.head(0)
    # print(result_df.shape)
    # print(df)
    for index in range(df.shape[0]):
        tmp_row=df.loc[index]
        tmp_index=get_valid_columns_index(tmp_row)
        # print(list(tmp_index))
        if set(tmp_index).issubset(valid_clomuns_index):
            pass
        else:
            difference_list=list(set(tmp_index).difference(valid_clomuns_index))
            
            location_list=[]
            tmp_difference_list=difference_list.copy()
            for item in difference_list:
                location=item
                #前后浮动位移（可优化）
                for i in range(1,3):
                    location=(item-i)
                    if location in valid_clomuns_index and location not in tmp_difference_list:
                        location_list.append(location)
                        tmp_difference_list.remove(item)
                        tmp_difference_list.append(location)
                        break
                    location=(item+i)
                    if location in valid_clomuns_index and location not in tmp_difference_list:
                        location_list.append(location)
                        tmp_difference_list.remove(item)
                        tmp_difference_list.append(location)
                        break
            result_location=list(df.columns)
            # print(location_list)
            # print(difference_list)
            # print("---------------------")
            for i in range(len(location_list)):
                result_location[difference_list[i]]=location_list[i]
                result_location[location_list[i]]=difference_list[i]
            # print(tmp_row)
            tmp_row=tmp_row.iloc[result_location].reset_index(drop=True)
            # print(tmp_row)
            # print(result_location)
        result_df=tmp_row.to_frame().T if result_df is None else pd.concat([result_df,tmp_row.to_frame().T])
    # print(np.array_equal(get_valid_columns_index(columns_list),get_valid_columns_index(result_df)))
    # print(list(set(get_valid_columns_index(columns_list)).difference(result_df)))
    # print(result_df)
    # print(result_df.shape)
    return result_df
def row_combine(sample_id,pdf_table):
# 将字符串转化成多维列表
    pdf_table=eval(pdf_table)

    table_result=[]
    start_rows_list=[]
    first_line_list=[]
    product_df_list=[]
    for item in pdf_table:
        #考虑加入一个判定表格位置的方法（暂缺）

        tmp_table_df=pd.DataFrame(item)
        tmp_table_df=tmp_table_df.fillna("").applymap(lambda x: x.replace("\n",""))
        #清除全空行
        drop_index_list=[]
        for index in range(tmp_table_df.shape[0]):
            judge=[]
            noshow=tmp_table_df.loc[index].map(lambda x:judge.append(x==""))
            if(False not in judge):
                drop_index_list.append(index)
        
        tmp_table_df=tmp_table_df.drop(drop_index_list).reset_index(drop=True)

        base_row=find_amt(tmp_table_df)

        tmp_row=None

        len_product_df_list=len(product_df_list)
        if base_row!=-1 and len_product_df_list!=0 :
            # print(product_df_list[len_product_df_list-1].shape)
            # print(table_result[len_product_df_list-1])
            if (product_df_list[len_product_df_list-1] is not None ) and (product_df_list[len_product_df_list-1].shape[0]==0):
                # print(table_result[len_product_df_list-1])
                tmp_row=table_result[len_product_df_list-1]

        if base_row==-1:
            if(len(table_result)>0):
                product_df=field_location_optimization(table_result[len(table_result)-1],tmp_table_df.loc[:].reset_index(drop=True))
                if(product_df is not None):
                    len_product_df_list=len(product_df_list)-1
                    product_df_list[len_product_df_list]=pd.concat([product_df_list[len_product_df_list],product_df])
                    # print(product_df.shape)
                else:
                    pass
            continue

        valid_columns_nums=[]
        len_df=None
        for index in range(0,base_row+1):
            len_list=tmp_table_df.loc[index].map(lambda x:len(x))
            for i in range(len(len_list)):
                if len_list[i]==0 and len_df is not None:
                    len_list[i]=len_df.tail(1)[i]
            len_df=pd.DataFrame(len_list).T if len_df is None else pd.concat([len_df,pd.DataFrame(len_list).T]).reset_index(drop=True)
            row_result=tmp_table_df.loc[index].map(lambda x:re.sub(r"$[ ]+?","",re.sub(r"^[ ]+?","",x)))
            tmp_row= row_result if tmp_row is None else tmp_row+row_result
            # valid_columns_nums.append(get_valid_columns_num(tmp_row))
        
        start_row=base_row+1

        for index in range(base_row+1,tmp_table_df.shape[0]):
            len_list=tmp_table_df.loc[index].map(lambda x:len(x))
            len_judge=(pd.DataFrame(len_list).T-len_df.loc[len_df.shape[0]-1]).reset_index(drop=True)
            len_judge=len_judge.T
            if(len_judge[len_judge[0]>0].shape[0]>0):
                break
            
            start_row+=1
            for i in range(len(len_list)):
                if len_list[i]==0 and len_df is not None:
                    len_list[i]=len_df.tail(1)[i]
            len_df=pd.DataFrame(len_list).T if len_df is None else pd.concat([len_df,pd.DataFrame(len_list).T]).reset_index(drop=True)
            row_result=tmp_table_df.loc[index].map(lambda x:re.sub(r"$[ ]+?","",re.sub(r"^[ ]+?","",x)))
            tmp_row= row_result if tmp_row is None else tmp_row+row_result

            # valid_columns_nums.append(get_valid_columns_num(tmp_row))
        
        columns_list=tmp_row.dropna().map(lambda x:x.replace(" ",""))
        valid_columns=find_valid_columns(tmp_table_df.iloc[start_row:,:])
        tmp_valid_columns=get_valid_columns_index(columns_list)
        # print(valid_columns)
        # print(tmp_valid_columns)

        difference=list(set(valid_columns).difference(tmp_valid_columns))
        # print(difference)


        # print("-------------")
        if(len(difference)>2):
            # print("---------")
            union_set=set(valid_columns).union(tmp_valid_columns)
            tmp_row[union_set]="添加字段"
            columns_list=tmp_row.dropna().map(lambda x:x.replace(" ",""))


        
        #处理错列问题
        product_df=field_location_optimization(columns_list,tmp_table_df.loc[start_row:].reset_index(drop=True))
        
        first_line=[]
        tmp_table_df.head(2).applymap(lambda x:first_line.append(x))
        first_line_result=[]
        for i in first_line:
            i=re.sub(r"^[ ]*?","",i)
            i=re.sub(r"$[ ]*?","",i)
            # i=re.sub(r"[ ]*?","",i)
            if i != "":
                first_line_result.append(i)
        table_result.append(columns_list)
        first_line_list.append(first_line_result)
        start_rows_list.append(start_row)
        product_df_list.append(product_df)
        # print(len(table_result))
        # print(len(first_line_list))
        # print(len(start_rows_list))
    return table_result,start_rows_list,first_line_list,product_df_list


def get_column_table(val_df):
    tmp_table_column={}
    tmp_table_column["sample_id"]=[]
    tmp_table_column["columns"]=[]
    tmp_table_column["start_row"]=[]
    tmp_table_column["first_line"]=[]
    tmp_table_column["product_df"]=[]
    for sample_id,tabel in tqdm(val_df[["sample_id","tabel"]].values):##修改使用的数据集
        table_result,start_rows_list,first_line_list,product_df_list=row_combine(sample_id,tabel)
        for i in range(len(start_rows_list)):
            valid_columns_index=get_valid_columns_index(table_result[i])
            tmp_table_column["sample_id"].append(sample_id)
            tmp_table_column["columns"].append(table_result[i].loc[valid_columns_index].T.reset_index(drop=True).T)
            tmp_table_column["start_row"].append(start_rows_list[i])
            tmp_table_column["first_line"].append(first_line_list[i])
            tmp_table_column["product_df"].append(product_df_list[i][valid_columns_index].T.reset_index(drop=True).T)

    tmp_table_column=pd.DataFrame(tmp_table_column)
    return tmp_table_column


val_table_column=get_column_table(val_df)
test_table_column=get_column_table(test_df)


# tmp_table_column[["columns","start_row","first_line"]]=val_df["tabel"].head(5).apply(lambda x:row_combine(x))


# tmp=val_df.iloc[177,:][["sample_id","tabel"]]
# table_result,start_rows_list,first_line_list,product_df_list=row_combine(tmp["sample_id"],tmp["tabel"])
# table_result
# product_df_list
# Out:
# 100%|██████████| 1800/1800 [06:22<00:00,  4.70it/s]
# 100%|██████████| 8660/8660 [16:34<00:00,  8.70it/s]

# %% [markdown]
# 表格内容拼接

# %%
from fuzzywuzzy import fuzz
from src.time_extractor import TimeFinder
import datetime


#寻找居中列，即只占一行的列
def find_min_columns(df):
    count_list=[]
    result=[]
    df.copy().T.apply(lambda x:count_list.append(get_valid_columns_num(x.T)),axis=1)
    # df.copy().T.apply(lambda x:print(x),axis=1)
    # print(count_list)
    max_count=np.max(count_list)
    while (0 in count_list):
        count_list[count_list.index(0)]=max_count
    min_count=np.min(count_list)
    index=0
    for item in count_list:
        if item ==min_count:
            result.append(index)
        index+=1
    # print(result)   
    return result
def judge_time_exist(df):
    judge_flag=[]
    t = TimeFinder()
    df.map(lambda x:judge_flag.append(t.find_time(x) is not None))
    if True not in judge_flag:
        return False
    else:
        return True
def get_each_product_row(columns_list,df):
    global column_neg_words
    global window_size
    if df.shape[0]==0:
        return None
    df=df.applymap(lambda x:str(x).replace(" ",""))
    max_valid_index_num=get_valid_columns_num(columns_list)

    #字段个数不足，跳过
    if(columns_list.shape[0]<=4):
        # print(1)
        return None

    #存在敏感词，即为无效答案，跳过
    judge_flag=[]    
    for word in column_neg_words:
        columns_list.map(lambda x:judge_flag.append(fuzz.partial_ratio(word,x)==100))
    if(True in judge_flag):
        # print(2)
        return None
    sum_rows=df.head(0)
    each_row=None

    #获取居中列
    min_columns_list=find_min_columns(df)
    max_index=-1
    # print(min_columns_list)
    for index in range(df.shape[0]):
        # print(str(index)+":------")
        # print(max_index)
        if index<=max_index:
            continue
        tmp_row=df.loc[index]
        # print(tmp_row.shape)
        tmp_valid_num=get_valid_columns_num(tmp_row)
        # print(tmp_valid_num)
        # print(max_valid_index_num)
        if tmp_valid_num>=max_valid_index_num-window_size:#第一种情况，列完整
            #判断是否存在时间
            # print(tmp_row)
            if(judge_time_exist(tmp_row)):
                each_row=tmp_row
                sum_rows=pd.concat([sum_rows,each_row.to_frame().T])
                each_row=None
                continue
            else:#不存在时间则视为不完整,加入each_row之后判断是否存在时间，存在即完整
                if each_row is None:
                    each_row=tmp_row
                else:
                    each_row=each_row+tmp_row
                if(judge_time_exist(each_row)):
                    sum_rows=pd.concat([sum_rows,each_row.to_frame().T])
                    each_row=None
                    continue
                else:
                    continue
                
        elif(tmp_valid_num==1 and sum_rows.shape[0]==0):#第二种情况，列不完整,且长度为1,且sum_row无内容，认为是少数的错误字段遗留数据，舍弃
            continue
        elif((index+1)!=df.shape[0]):#第三种情况，列不完整，需要多行拼加
            #寻找目前剩下的矩阵中与当前行以外存在值的最浅的居中列
            
            start_row=index+1
            remain_df=df.iloc[start_row:,min_columns_list]
            middle_index=index+1
            middle_column=min_columns_list[0]
            # print(middle_column)
            for i in list(remain_df.index):
                valid_columns_index=get_valid_columns_index(remain_df.loc[i])
                if(len(valid_columns_index))>0:
                    middle_index=i
                    middle_column=valid_columns_index[0]
                    break
            # print(index)
            # print("middle")
            # print(middle_index)

            len_df=None

            start_row=index
            end_row=middle_index*2-index+1 if middle_index*2-index+1<=df.shape[0] else df.shape[0]
            for i in range(start_row,end_row):
                # print(df.shape)
                if(get_valid_columns_num(df.loc[i])>=max_valid_index_num-window_size):#强制中断条件
                    break
                max_index=i
                len_list=df.loc[i].map(lambda x:len(re.sub("[A-Za-z]*?","",x)))
                for j in range(len(len_list)):
                    if len_list[j]==0 and len_df is not None:
                        len_list[j]=len_df.tail(1)[j]
                len_df=pd.DataFrame(len_list).T if len_df is None else pd.concat([len_df,pd.DataFrame(len_list).T]).reset_index(drop=True)
                each_row=df.loc[i] if each_row is None else each_row+df.loc[i]
            

            start_row=max_index+1
            # print(start_row)
            # print(max_index)
            # print(len_df)

            for i in range(start_row,df.shape[0]):
                # print(df.shape)
                if(get_valid_columns_num(df.loc[i])>=max_valid_index_num-window_size):#强制中断条件
                    break
                len_list=df.loc[i].map(lambda x:len(re.sub("[A-Za-z]*?","",x)))
                # print(len_df)
                len_judge=(pd.DataFrame(len_list).T-len_df.loc[len_df.shape[0]-1]).reset_index(drop=True)
                len_judge=len_judge.T
                # print(len_judge)
                if(len_judge[len_judge[0]>0].shape[0]>0):
                    break
                max_index=i
                # print("max")
                # print(max_index)
                for j in range(len(len_list)):
                    if len_list[j]==0 and len_df is not None:
                        len_list[j]=len_df.tail(1)[j]
                len_df=pd.DataFrame(len_list).T if len_df is None else pd.concat([len_df,pd.DataFrame(len_list).T]).reset_index(drop=True)
                each_row=df.loc[i] if each_row is None else each_row+df.loc[i]
            



            if(judge_time_exist(each_row)):
                sum_rows=pd.concat([sum_rows,each_row.to_frame().T])
                each_row=None
                continue
            else:
                each_row=None
                continue
    # print(sum_rows)
    return sum_rows


column_neg_words=["实际收回","收回","赎回","实际获得","实际损益","收益情况","投资盈亏","投资收益","理财盈亏","理财收益","盈亏","收益（元","收益(元","收益(万元","收益（万元","到期收益","到期收","是否到","是否已","目前状","到期情","到息情"]


window_size=1##到时浮动（0-2）选择行数最多的一次
def get_result_matrix(tmp_table_column):

    sum_product_df=[]
    index=0
    index_list=[]
    for sample_id,columns_list,product_df in tqdm(tmp_table_column[["sample_id","columns","product_df"]].values):
        # product_df
        if(columns_list is None or product_df is None):
            continue
        # sample_id
        each_sum_rows=get_each_product_row(columns_list,product_df.reset_index(drop=True))
        if(each_sum_rows is not None):
            sum_product_df.append(each_sum_rows)
            index_list.append(index)
        index+=1

    result_matrix=tmp_table_column.iloc[index_list,:]
    result_matrix["product_df"]=sum_product_df

    return result_matrix

val_result_matrix=get_result_matrix(val_table_column)
test_result_matrix=get_result_matrix(test_table_column)
# Out:
# 100%|██████████| 2162/2162 [06:05<00:00,  5.91it/s]
# 100%|██████████| 9025/9025 [15:52<00:00,  9.47it/s]

# %% [markdown]
# #### 4.抽取的是单独的数据包含
# #### 起息日，到息日， 金额，认购日期，产品发行方，理财产品

# %%
    
def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        pass
 
    try:
        import unicodedata
        unicodedata.numeric(s)
        return True
    except (TypeError, ValueError):
        pass
    return False

def judge_type(columns):
    type_index=[]#1:产品名,2:金额,3:发行方，4:期限
    columns=columns.map(lambda x:x.replace("（","(").replace("）",")"))
    product_name_pos_words=["产品名称","产品名册","产品名","理财产品","项目名","回购名","回购品","标的名","金融产","投资项"]#"存款种类","基金类型"#不能为空
    # product_name_neg_words=["编号","代码"]
    amt_pos_words=["存款金","认购金","投资金","投入金","受托金","理财金","金额","（元","(元","(万元","（万元","(亿元","（亿元","人民币","投资规","认购规","存款规","投入规","理财规"]
    counter_name_pos_words=["受托方","银行机","机构名","合作方名","合作银","合作机","受托人","发行主","签约方","协议方","受托机","受托银","认购银","签约银","签约机","协议机","发生主","存放银","存款银","存款机","存放机","购买银","购买机","管理人","管理银","管理机","银行名","发行机","发行主","发行人","对手方","开户银","开户行","开户机"]#可以为空
    time_length_pos_words=["期限","(天)","持有时间"]
    for words in product_name_pos_words:
        judge_flag=[]
        columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==100))
        # columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==0))
        if True in judge_flag:
            type_index.append(judge_flag.index(True))
            break
    if(len(type_index)==0):
        for words in ["种类","类型","类别"]:
            judge_flag=[]
            columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==100))
            # columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==0))
            if True  in judge_flag:
                type_index.append(judge_flag.index(True))
                break
        if(len(type_index)==0):
            type_index.append(-1)
        

    for words in amt_pos_words:
        judge_flag=[]
        columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==100))
        if True  in judge_flag:
            type_index.append(judge_flag.index(True))
            break
    if(len(type_index)==1):
        type_index.append(-1)
    
    for words in counter_name_pos_words:
        judge_flag=[]
        columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==100))
        if True  in judge_flag:
            type_index.append(judge_flag.index(True))
            break
    if(len(type_index)==2):
        type_index.append(-1)
    
    for words in time_length_pos_words:
        judge_flag=[]
        columns.map(lambda x:judge_flag.append(fuzz.partial_ratio(words,x)==100))
        if True  in judge_flag:
            type_index.append(judge_flag.index(True))
            break
    if(len(type_index)==3):
        type_index.append(-1)
    
    
    return type_index
def get_answer_matrix(result_matrix,sample_id=None):

    temp_single={}
    temp_single['认购日期'] = []
    temp_single['产品起息日'] = []
    temp_single['产品到息日'] = []
    temp_single['产品期限'] = []
    temp_single['认购金额(万元)'] = []
    temp_single['产品发行方名称'] = []
    temp_single['理财产品名称'] = []
    temp_single['sample_id'] = []

    if(sample_id is not None):
        result_matrix=result_matrix[result_matrix["sample_id"]==sample_id]
    for sample_id,columns,product_df in tqdm(result_matrix[["sample_id","columns","product_df"]].values):
        
        type_index=judge_type(columns)
        # product_df
        # columns
        # type_index
        for index in product_df.index:
            tmp_df=product_df.loc[index]
            if(len(tmp_df.shape) ==2 ):
                tmp_df=tmp_df.reset_index(drop=True).loc[0]
            product_name=""
            amt=""
            counter_name=""
            pur_dt=""
            val_dt=""
            coupon_dt=""
            time_limit=""
            #产品名
            if(type_index[0]!=-1):
                if (str(grocery.predict(tmp_df.loc[type_index[0]])) == "理财产品"):
                    product_name=tmp_df.loc[type_index[0]]
            else:
                candidate_list={}
                candidate_list["理财产品"]=[]
                candidate_list["发行方"]=[]
                candidate_list["其它"]=[]
                candidate_list["购买公司"]=[]
                for each_word in tmp_df.head(1):
                    if not (is_number(each_word)):
                        candidate_list[str(grocery.predict(each_word))].append(each_word)
                if(len(candidate_list["理财产品"])!=0):
                    product_name=candidate_list["理财产品"][0]
            #金额
            if(type_index[1]!=-1):
                amt=tmp_df.loc[type_index[1]].replace("（","").replace("）","").replace("(","").replace("(","").replace("元","").replace("圆","")
                type_amt=0
                if("万" in amt or "万" in columns.loc[type_index[1]]):
                    type_amt=1
                if("亿" in amt or "亿" in columns.loc[type_index[1]]):
                    type_amt=2
                amt=re.sub("[^0-9.]","",amt)
                if(is_number(amt)):
                    amt=float(amt)
                    if(type_amt==0 and amt/10000 >float(50)):
                        amt/=10000
                    if(type_amt==2):
                        amt*=10000
                # print(amt)
            else:
                candidate_list=[]
                value_list=list(tmp_df)
                for item in value_list:
                    tmp=str(item).replace("（","").replace("）","").replace("(","").replace("(","").replace("元","").replace("圆","").replace("亿","").replace("万","")
                    if(is_number(tmp)):
                        candidate_list.append(float(tmp))

                if len(candidate_list)>0:
                    real_tmp=sorted(candidate_list,reverse=True)[0]

                    for item in value_list:
                        tmp=str(item).replace("（","").replace("）","").replace("(","").replace("(","").replace("元","").replace("圆","").replace("亿","").replace("万","")
                        if(is_number(tmp) and float(tmp)==real_tmp):
                            amt=item
                            type_amt=0
                        else:
                            continue
                        if("万" in amt ):
                            type_amt=1
                        if("亿" in amt ):
                            type_amt=2
                        amt=re.sub("[^0-9.]","",amt)
                        if(is_number(amt)):
                            amt=float(amt)
                            # print(amt)
                            if(type_amt==0 and amt/10000 >float(50)):
                                amt/=10000
                            if(type_amt==2):
                                amt*=10000
                        if(amt !="" or amt!=np.nan):
                            break
            #发行方
            if(type_index[2]!=-1):
                if (str(grocery.predict(tmp_df.loc[type_index[2]])) == "发行方"):
                    counter_name=tmp_df.loc[type_index[2]]
            else:
                candidate_list={}
                candidate_list["理财产品"]=[]
                candidate_list["发行方"]=[]
                candidate_list["其它"]=[]
                candidate_list["购买公司"]=[]
                for each_word in tmp_df.head(1):
                    if not (is_number(each_word)):
                        candidate_list[str(grocery.predict(each_word))].append(each_word)
                if(len(candidate_list["发行方"])!=0):
                    counter_name=candidate_list["发行方"][0]
            
            #期限
            if(type_index[3]!=-1):
                text=str(tmp_df.loc[type_index[3]])
                # print(text)
                a=re.search("\d+?[天]+?",text)
                if (a is None):
                    a=re.search("\d+?[个]+[月]+?",text)
                if a is None:
                    a=re.search("[^\d]\d[年]+?",text)
                    if(a is not None):
                        a=re.search("\d[年]+?",a.group())
                if a is None:
                    a=re.search("^\d[年]+?",text)
                if a is not None:
                    time_limit=a.group().replace("（","").replace("）","").replace("(","").replace("(","")
                else:
                    if(is_number(text)):
                        time_limit=str(text)+"天"
                        # print(time_limit)
                    else:
                        time_limit=""

            #三个日期
            # tmp_df
            value_list=[]
            noshow=tmp_df.map(lambda x:value_list.append(str(x)))
            sum_value=(" and ").join(i for i in value_list)
            t = TimeFinder()
            time_all = t.find_time(sum_value)
            # print(time_all)
            if(time_all is not None):
                time_all=sorted(list(set(time_all)),reverse=True)
                # print(len(time_all))
                # print(sum_value)
                # print(product_name)
                if(len(time_all)==1):
                    pur_dt=time_all[0]
                    val_dt=pur_dt
                elif(len(time_all)==2):
                    # time_all=sorted(list(set(time_all)),reverse=True)
                    if(re.search("随时",sum_value) is not None or re.search("工作日",sum_value)):
                        time_limit=""
                        pur_dt=time_all[1]
                        val_dt=time_all[0]
                        coupon_dt = ""
                    else:
                        pur_dt=time_all[1]
                        val_dt=time_all[1]
                        coupon_dt = time_all[0]
                        try:
                            # 相减
                            if(type_index[3]==-1 or time_limit==""):
                                d1 = datetime.datetime.strptime(val_dt, '%Y-%m-%d')
                                d2 = datetime.datetime.strptime(coupon_dt, '%Y-%m-%d')
                                d = d2 - d1
                                time_limit = str(d.days) + '天'
                        except Exception:
                            coupon_dt = ""
                            time_limit = ""
                elif(len(time_all)==3):
                        # print(time_all)
                        pur_dt=time_all[2]
                        val_dt=time_all[1]
                        coupon_dt = time_all[0]
                        try:
                            # 相减
                            d1 = datetime.datetime.strptime(pur_dt, '%Y-%m-%d')
                            d2 = datetime.datetime.strptime(val_dt, '%Y-%m-%d')
                            d = d2 - d1
                            if str(d.days)=="1":
                                d1 = datetime.datetime.strptime(val_dt, '%Y-%m-%d')
                                d2 = datetime.datetime.strptime(coupon_dt, '%Y-%m-%d')
                                d = d2 - d1
                                time_limit=str(d.days)+"天"
                            else:
                                pur_dt=time_all[2]
                                val_dt=pur_dt
                                coupon_dt=""
                        except Exception:
                            coupon_dt = ""
                            time_limit = ""
                elif(len(time_all)>4):
                        time_all=sorted(time_all)
                        pur_dt=time_all[0]
                        val_dt=""
                        coupon_dt=""
                if pur_dt!="" and coupon_dt=="" and time_limit!="":
                    try:
                        coupon_dt=datetime.datetime.strftime(datetime.datetime.strptime(pur_dt, '%Y-%m-%d')+datetime.timedelta(days=int(re.search("\d*",time_limit).group())), '%Y-%m-%d')
                    except:
                        pass

            temp_single['认购日期'].append(pur_dt)
            temp_single['产品起息日'].append(val_dt)
            temp_single['产品到息日'].append(coupon_dt)
            temp_single['产品期限'] .append(time_limit)
            temp_single['认购金额(万元)'].append(amt)
            temp_single['产品发行方名称'] .append(counter_name)
            temp_single['理财产品名称'] .append(product_name)
            temp_single['sample_id'].append(sample_id)
        
    temp_single=pd.DataFrame(temp_single)
    return temp_single

val_temp_single=get_answer_matrix(val_result_matrix)
test_temp_single=get_answer_matrix(test_result_matrix)
# Out:
# 100%|██████████| 1122/1122 [04:48<00:00,  3.89it/s]
# 100%|██████████| 5481/5481 [12:39<00:00,  7.22it/s]

# %% [markdown]
# #### 5.汇总整理数据

# %% [markdown]
# temp_single裁剪

# %%
def drop_judge(judge_title_result,result,score_limit=31):
    # global judge_title_result
    drop_list=[]
    index=0
    for sample_id,product_name in tqdm(result[["sample_id","理财产品名称"]].values):
        # print(sample_id)
        score_list=[]
        for text in judge_title_result[judge_title_result["sample_id"]==int(sample_id)][4].values:
            # print(text)
            score_list.append(fuzz.partial_token_sort_ratio(product_name,text))
        # print(score_list)
        if  len(score_list)>0 and np.max(pd.DataFrame(score_list)[0])<=score_limit:
            drop_list.append(index)
        index+=1 
    
    return result.copy().reset_index(drop=True).drop(drop_list)

# drop_judge(r)

# %%
def get_result(judge_title_result,time_list,gm_list,result_matrix):
    tmp_result=pd.merge(time_list,gm_list,on=["sample_id"])
    tmp_result["sample_id"]=tmp_result["sample_id"].astype(str)
    r=result_matrix.fillna("").reset_index(drop=True)
    i=0
    i_list=[]
    for index in r.index:
        if r.loc[index].dropna().shape[0]<=5 or type(r.loc[index]["理财产品名称"]) is float or len(r.loc[index]["理财产品名称"])<2:
            i_list.append(i)
        i+=1
    r=r.drop(i_list)
    r=r.fillna("").applymap(lambda x:str(x).replace(" ",""))
    r=drop_judge(judge_title_result,r)


    result=pd.merge(tmp_result,r,on=["sample_id"]).reset_index(drop=True)
    return result

val_result=get_result(val_judge_title_result,val_time,val_gm,val_temp_single)
test_result=get_result(test_judge_title_result,test_time,test_gm,test_temp_single)
# Out:
# 100%|██████████| 6022/6022 [00:15<00:00, 388.87it/s]
# 100%|██████████| 15718/15718 [00:39<00:00, 397.37it/s]

# %%
  def get_F1(val_pred, val_true):
      val_pred = list(val_pred)
      val_true = list(val_true)
      curr = list(set(val_pred).intersection(set(val_true)))
      R = len(curr)/len(val_true)
      P = len(curr)/len(val_pred)
      return 2*P*R/(P+R)

  r = pd.merge(val_df[['sample_id']], train_outputs, on='sample_id', how='left')
  val_true = r['sample_id'].astype(str) + r['理财产品名称'].astype(str) + r['认购金额(万元)'].astype(str) +r['产品发行方名称'].astype(str) + r['认购日期'].astype(str) + r['产品起息日'].astype(str)+ r['产品到息日'].astype(str) + r['产品期限'].astype(str)+ r['公告日期'].astype(str)+ r['实际购买公司名称'].astype(str)
    # r.to_excel("result_after_drop.xlsx",index=None)
  
r=val_result


val_pred = r['sample_id'].astype(str) + r['理财产品名称'].astype(str) + r['认购金额(万元)'].astype(str) +r['产品发行方名称'].astype(str) + r['认购日期'].astype(str) + r['产品起息日'].astype(str)+ r['产品到息日'].astype(str) + r['产品期限'].astype(str)+ r['公告日期'].astype(str)+ r['实际购买公司名称'].astype(str)
score = get_F1(val_pred, val_true)
score
# Out:
# 0.06043437204910292

# %% [markdown]
# # 建模过程（预处理模型）

# %% [markdown]
# ### 1.采用LSTM网络用提取好的部分跟pdf中的text做交互预测
# #### 理财类型、资金来源、实际购买公司和上市公司关系、买卖方是否有关联关系

# %%
# 最后一部分字段采用预测好的部分，跟提取的text做交互采用双输入lstm在dense层做交互预测最后几个字段
train_lstm_input = pd.merge(train_df, train_outputs, on='sample_id', how='left')
train_lstm_input = train_lstm_input.fillna('否')
# label_1理财类型-10  label_2资金来源-3 label_3实际购买公司和上市公司关系-3 label_4买卖方是否有关联关系-2
from sklearn.preprocessing import LabelEncoder
label_1 = LabelEncoder()
label_2 = LabelEncoder()
label_3 = LabelEncoder()
label_4 = LabelEncoder()

train_data = pd.DataFrame()
train_data['text_1'] = train_lstm_input['理财产品名称'].astype(str) + '_' + train_lstm_input['产品发行方名称'].astype(str)
train_data['text_2'] = train_lstm_input['text'].astype(str)

train_data['label_1'] = label_1.fit_transform(train_lstm_input['理财类型'])
train_data['label_2'] = label_2.fit_transform(train_lstm_input['资金来源'])
train_data['label_3'] = label_3.fit_transform(train_lstm_input['实际购买公司和上市公司关系'])
train_data['label_4'] = label_4.fit_transform(train_lstm_input['买卖方是否有关联关系'])

# %%
# 导入相关库
import os
import pandas as pd
from tqdm.autonotebook import *
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.metrics import accuracy_score
import time
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.sparse import hstack
from sklearn.model_selection import StratifiedKFold
from gensim.models import FastText, Word2Vec
import re
from keras.layers import *
from keras.models import *
from keras.preprocessing.text import Tokenizer, text_to_word_sequence
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing import text, sequence
from keras.callbacks import *
from keras.layers.advanced_activations import LeakyReLU, PReLU
import keras.backend as K
from keras.optimizers import *
from keras.utils import to_categorical
import tensorflow as tf
import random as rn
import gc
import logging
import gensim
import jieba
tqdm.pandas()
os.environ['PYTHONHASHSEED'] = '0'
# 显卡使用（如没显卡需要注释掉）
os.environ['CUDA_VISIBLE_DEVICES'] = "0"
np.random.seed(1024)
rn.seed(1024)
tf.random.set_seed(1024)

# %%
train_data['text_1'] = train_data['text_1'].progress_apply(lambda row:' '.join(jieba.lcut(str(row))))
train_data['text_2'] = train_data['text_2'].progress_apply(lambda row:' '.join(jieba.lcut(str(row))))
train_data.head(5)
# Out:
# 100%|██████████| 27154/27154 [00:03<00:00, 7517.09it/s]
# 100%|██████████| 27154/27154 [12:18<00:00, 36.76it/s]
#                                                            text_1  \
# 0               中银 保本 理财 - 人民币 按期 开放 理财产品 _ 中国银行 股份 有限公司 广州 东山 支行
# 1               中银 保本 理财 - 人民币 按期 开放 理财产品 _ 中国银行 股份 有限公司 广州 东山 支行
# 2                               与 利率 挂钩 的 结构性 产品 _ 中国民生银行 股份 有限公司
# 3            广发 银行 “ 薪 加薪 ” 16 号 XJXCKJ2578 _ 广发 银行 股份 有限公司 清远 分行
# 4  兴业银行 “ 金 雪球 - 优悦 ” 保本 开放式 人民币 理财产品 ( 2M ) _ 兴业银行 股份 有限公司 芜湖 分行
#
#                                                                                                 text_2  \
# 0  [ ' 证券 代码 ： 600728                 证券 简称 ： 佳 都 科技                   公告 编号 ： 2016 - 099   \ n   \...
# 1  [ ' 证券 代码 ： 600728                 证券 简称 ： 佳 都 科技                   公告 编号 ： 2016 - 099   \ n   \...
# 2  [ ' 证券 代码 ： 600211                             证券 简称 ： 西藏药业                           公告 编号 ： 20...
# 3  [ ' 证券 代码 ： 002171                               证券 简称 ： 楚江 新材                               公告 ...
# 4  [ ' 证券 代码 ： 002171                               证券 简称 ： 楚江 新材                               公告 ...
#
#    label_1  label_2  label_3  label_4
# 0        9        1        0        0
# 1        9        1        0        0
# 2        9        0        0        0
# 3        9        1        2        0
# 4        9        1        0        0

# %%
### Tokenizer 序列化文本
def set_tokenizer(docs, split_char=' ', max_len=100):
    '''
    输入
    docs:文本列表
    split_char:按什么字符切割
    max_len:截取的最大长度
    
    输出
    X:序列化后的数据
    word_index:文本和数字对应的索引
    '''
    tokenizer = Tokenizer(lower=False, char_level=False, split=split_char)
    tokenizer.fit_on_texts(docs)
    X = tokenizer.texts_to_sequences(docs)
    maxlen = max_len
    X = pad_sequences(X, maxlen=maxlen, value=0)
    word_index=tokenizer.word_index
    return X, word_index, tokenizer

### 做embedding 这里采用word2vec 可以换成其他例如（glove词向量）
def trian_save_word2vec(docs, embed_size=300, save_name='w2v.txt', split_char=' '):
    '''
    输入
    docs:输入的文本列表
    embed_size:embed长度
    save_name:保存的word2vec位置
    
    输出
    w2v:返回的模型
    '''
    input_docs = []
    for i in docs:
        input_docs.append(i.split(split_char))
    logging.basicConfig(
    format='%(asctime)s:%(levelname)s:%(message)s', level=logging.INFO)
    w2v = Word2Vec(input_docs, size=embed_size, sg=1, window=8, seed=1017, workers=24, min_count=1, iter=10)
    w2v.save(save_name)
    print("w2v model done")
    return w2v

# 得到embedding矩阵
def get_embedding_matrix(word_index, embed_size=300, Emed_path="w2v_300.txt"):
    embeddings_index = Word2Vec.load(Emed_path)
    nb_words = len(word_index)+1
    embedding_matrix = np.zeros((nb_words, embed_size))
    count = 0
    for word, i in tqdm(word_index.items()):
        if i >= nb_words:
            continue
        try:
            embedding_vector = embeddings_index[word]
        except:
            embedding_vector = np.zeros(embed_size)
            count += 1
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector  
    print("null cnt",count)
    return embedding_matrix

# 得到fasttext矩阵
def load_fasttext(word_index, path):  
    count=0
    null_list=[]
    def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
    embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(path, encoding='utf-8') if len(o)>100)

    all_embs = np.stack(embeddings_index.values())
    emb_mean,emb_std = all_embs.mean(), all_embs.std()
    embed_size = all_embs.shape[1]

    # word_index = tokenizer.word_index
    nb_words =  len(word_index)+1
    embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
    for word, i in word_index.items():
        if i >= nb_words: continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None: 
            embedding_matrix[i] = embedding_vector
        else:
            null_list.append(word)
            count+=1
    print("null cnt:",count)
    return embedding_matrix

def get_embedding_matrix_txt(word_index,embed_size=200,Emed_path="w2v_300.txt"):
    embeddings_index = gensim.models.KeyedVectors.load_word2vec_format(
        Emed_path, binary=False)
    nb_words = len(word_index)+1
    embedding_matrix = np.zeros((nb_words, embed_size))
    count = 0
    for word, i in tqdm(word_index.items()):
        if i >= nb_words:
            continue
        try:
            embedding_vector = embeddings_index[word]
        except:
            embedding_vector = np.zeros(embed_size)
            count += 1
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    print("null cnt",count)
    return embedding_matrix

# %% [markdown]
# ### 2.训练得到word2vec

# %%
text_1_list = np.unique(train_data['text_1'])
text_3_list = np.unique(train_data['text_2'])

print('开始序列化')
x1, index_1, token_1 = set_tokenizer(train_data['text_1'], split_char=' ', max_len=30)
x3, index_3, token_3 = set_tokenizer(train_data['text_2'], split_char=' ', max_len=600)
print('序列化完成')
gc.collect()

trian_save_word2vec(text_1_list, save_name='models/w2v_300_1.txt', split_char=' ')
gc.collect()
trian_save_word2vec(text_3_list, save_name='models/w2v_300_3.txt', split_char=' ')
gc.collect()

# 得到emb矩阵
emb1 = get_embedding_matrix(index_1, Emed_path='models/w2v_300_1.txt')
emb3 = get_embedding_matrix(index_3, Emed_path='models/w2v_300_3.txt')
gc.collect()
# Out:
# 开始序列化
# 序列化完成
# 22
# 33:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:40,238:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:40,250:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:40,254:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:40,267:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:40,270:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:40,276:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:40,285:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:40,288:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:40,291:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:40,296:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:40,302:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:40,305:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:40,309:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:40,313:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:40,329:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:40,345:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:40,347:INFO:EPOCH - 2 : training on 175141 raw words (106485 effective words) took 0.3s, 327276 effective words/s
# 2020-09-08 16:03:40,381:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:40,386:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:40,389:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:40,394:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:40,427:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:40,436:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:40,524:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:40,532:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:40,576:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:40,592:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:40,595:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:40,598:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:40,609:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:40,619:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:40,621:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:40,636:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:40,639:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:40,644:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:40,660:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:40,663:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:40,664:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:40,670:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:40,677:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:40,696:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:40,698:INFO:EPOCH - 3 : training on 175141 raw words (106441 effective words) took 0.3s, 322503 effective words/s
# 2020-09-08 16:03:40,738:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:40,750:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:40,755:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:40,775:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:40,788:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:40,806:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:40,876:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:40,958:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:40,966:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:40,983:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:40,989:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:40,992:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:40,994:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:40,999:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:41,003:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:41,004:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:41,009:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:41,013:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:41,035:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:41,038:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:41,042:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:41,051:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:41,056:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:41,059:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:41,060:INFO:EPOCH - 4 : training on 175141 raw words (106619 effective words) took 0.3s, 311286 effective words/s
# 2020-09-08 16:03:41,099:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:41,116:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:41,121:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:41,125:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:41,149:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:41,173:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:41,252:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:41,331:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:41,348:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:41,355:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:41,361:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:41,365:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:41,375:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:41,378:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:41,380:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:41,381:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:41,387:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:41,390:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:41,400:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:41,404:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:41,408:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:41,412:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:41,424:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:41,428:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:41,430:INFO:EPOCH - 5 : training on 175141 raw words (106413 effective words) took 0.3s, 308520 effective words/s
# 2020-09-08 16:03:41,469:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:41,474:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:41,511:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:41,513:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:41,524:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:41,567:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:41,648:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:41,652:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:41,676:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:41,680:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:41,685:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:41,697:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:41,704:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:41,707:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:41,716:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:41,723:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:41,739:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:41,743:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:41,745:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:41,753:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:41,756:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:41,759:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:41,764:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:41,782:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:41,784:INFO:EPOCH - 6 : training on 175141 raw words (106594 effective words) took 0.3s, 324738 effective words/s
# 2020-09-08 16:03:41,821:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:41,823:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:41,825:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:41,833:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:41,844:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:41,856:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:41,951:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:41,985:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:42,002:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:42,008:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:42,027:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:42,029:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:42,031:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:42,034:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:42,045:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:42,053:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:42,057:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:42,067:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:42,070:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:42,075:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:42,089:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:42,101:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:42,105:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:42,111:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:42,112:INFO:EPOCH - 7 : training on 175141 raw words (106585 effective words) took 0.3s, 346923 effective words/s
# 2020-09-08 16:03:42,142:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:42,144:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:42,147:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:42,160:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:42,180:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:42,187:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:42,223:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:42,340:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:42,347:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:42,355:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:42,364:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:42,371:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:42,374:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:42,378:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:42,388:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:42,390:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:42,392:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:42,405:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:42,408:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:42,409:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:42,413:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:42,419:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:42,432:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:42,438:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:42,440:INFO:EPOCH - 8 : training on 175141 raw words (106741 effective words) took 0.3s, 346901 effective words/s
# 2020-09-08 16:03:42,474:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:42,478:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:42,479:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:42,497:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:42,508:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:42,523:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:42,561:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:42,648:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:42,670:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:42,682:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:42,689:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:42,693:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:42,696:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:42,715:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:42,729:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:42,732:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:42,734:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:42,737:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:42,739:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:42,741:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:42,756:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:42,765:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:42,770:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:42,774:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:42,776:INFO:EPOCH - 9 : training on 175141 raw words (106661 effective words) took 0.3s, 340151 effective words/s
# 2020-09-08 16:03:42,838:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:03:42,839:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:03:42,842:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:03:42,857:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:03:42,877:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:03:42,892:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:03:42,970:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:03:43,054:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:03:43,058:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:03:43,061:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:03:43,067:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:03:43,075:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:03:43,080:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:03:43,084:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:03:43,086:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:03:43,090:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:03:43,094:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:03:43,096:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:03:43,098:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:03:43,112:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:03:43,128:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:03:43,131:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:03:43,136:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:03:43,150:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:03:43,152:INFO:EPOCH - 10 : training on 175141 raw words (106712 effective words) took 0.3s, 316268 effective words/s
# 2020-09-08 16:03:43,153:INFO:training on a 1751410 raw words (1065878 effective words) took 3.5s, 306048 effective words/s
# 2020-09-08 16:03:43,154:WARNING:under 10 jobs per worker: consider setting a smaller `batch_words' for smoother alpha decay
# 2020-09-08 16:03:43,155:INFO:saving Word2Vec object under models/w2v_300_1.txt, separately None
# 2020-09-08 16:03:43,155:INFO:not storing attribute vectors_norm
# 2020-09-08 16:03:43,156:INFO:not storing attribute cum_table
# 2020-09-08 16:03:43,334:INFO:saved models/w2v_300_1.txt
# w2v model done
# 0
# 8:55,994:INFO:EPOCH 8 - PROGRESS: at 19.58% examples, 223479 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:08:57,023:INFO:EPOCH 8 - PROGRESS: at 21.47% examples, 227266 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:08:58,032:INFO:EPOCH 8 - PROGRESS: at 23.24% examples, 225689 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:08:59,042:INFO:EPOCH 8 - PROGRESS: at 25.36% examples, 226416 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:00,069:INFO:EPOCH 8 - PROGRESS: at 28.01% examples, 226015 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:09:01,076:INFO:EPOCH 8 - PROGRESS: at 30.84% examples, 227683 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:02,079:INFO:EPOCH 8 - PROGRESS: at 32.79% examples, 226986 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:03,151:INFO:EPOCH 8 - PROGRESS: at 34.84% examples, 229045 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:04,162:INFO:EPOCH 8 - PROGRESS: at 36.15% examples, 232718 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:05,245:INFO:EPOCH 8 - PROGRESS: at 38.93% examples, 236127 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:06,253:INFO:EPOCH 8 - PROGRESS: at 40.58% examples, 236253 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:07,307:INFO:EPOCH 8 - PROGRESS: at 42.15% examples, 240470 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:08,318:INFO:EPOCH 8 - PROGRESS: at 44.35% examples, 241589 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:09,394:INFO:EPOCH 8 - PROGRESS: at 46.24% examples, 243499 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:10,402:INFO:EPOCH 8 - PROGRESS: at 47.91% examples, 245331 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:11,409:INFO:EPOCH 8 - PROGRESS: at 50.44% examples, 247108 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:12,420:INFO:EPOCH 8 - PROGRESS: at 52.58% examples, 247376 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:09:13,464:INFO:EPOCH 8 - PROGRESS: at 55.43% examples, 248706 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:09:14,467:INFO:EPOCH 8 - PROGRESS: at 57.75% examples, 251053 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:15,473:INFO:EPOCH 8 - PROGRESS: at 59.53% examples, 251163 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:16,475:INFO:EPOCH 8 - PROGRESS: at 61.34% examples, 251368 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:17,479:INFO:EPOCH 8 - PROGRESS: at 63.59% examples, 250326 words/s, in_qsize 44, out_qsize 3
# 2020-09-08 16:09:18,498:INFO:EPOCH 8 - PROGRESS: at 67.00% examples, 249517 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:19,504:INFO:EPOCH 8 - PROGRESS: at 69.97% examples, 249018 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:20,562:INFO:EPOCH 8 - PROGRESS: at 72.74% examples, 248348 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:21,568:INFO:EPOCH 8 - PROGRESS: at 76.35% examples, 248910 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:22,583:INFO:EPOCH 8 - PROGRESS: at 78.63% examples, 248006 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:23,600:INFO:EPOCH 8 - PROGRESS: at 81.86% examples, 247828 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:24,602:INFO:EPOCH 8 - PROGRESS: at 84.57% examples, 247549 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:25,610:INFO:EPOCH 8 - PROGRESS: at 87.54% examples, 246657 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:26,681:INFO:EPOCH 8 - PROGRESS: at 90.92% examples, 246140 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:27,721:INFO:EPOCH 8 - PROGRESS: at 94.64% examples, 246132 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:28,729:INFO:EPOCH 8 - PROGRESS: at 97.10% examples, 245133 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:29,264:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:09:29,287:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:09:29,288:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:09:29,289:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:09:29,290:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:09:29,294:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:09:29,296:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:09:29,297:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:09:29,298:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:09:29,299:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:09:29,322:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:09:29,369:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:09:29,371:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:09:29,393:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:09:29,396:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:09:29,403:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:09:29,432:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:09:29,440:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:09:29,444:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:09:29,454:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:09:29,456:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:09:29,464:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:09:29,480:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:09:29,511:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:09:29,513:INFO:EPOCH - 8 : training on 21113789 raw words (10776549 effective words) took 43.8s, 246088 effective words/s
# 2020-09-08 16:09:30,668:INFO:EPOCH 9 - PROGRESS: at 1.09% examples, 146764 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:31,672:INFO:EPOCH 9 - PROGRESS: at 2.19% examples, 174513 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:32,689:INFO:EPOCH 9 - PROGRESS: at 3.94% examples, 197551 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:33,700:INFO:EPOCH 9 - PROGRESS: at 6.36% examples, 208938 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:34,730:INFO:EPOCH 9 - PROGRESS: at 7.82% examples, 213013 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:35,777:INFO:EPOCH 9 - PROGRESS: at 9.87% examples, 213528 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:09:36,788:INFO:EPOCH 9 - PROGRESS: at 12.27% examples, 223318 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:37,831:INFO:EPOCH 9 - PROGRESS: at 15.08% examples, 230092 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:38,865:INFO:EPOCH 9 - PROGRESS: at 18.10% examples, 234764 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:39,930:INFO:EPOCH 9 - PROGRESS: at 20.65% examples, 239628 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:40,930:INFO:EPOCH 9 - PROGRESS: at 22.54% examples, 241020 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:41,968:INFO:EPOCH 9 - PROGRESS: at 25.39% examples, 245115 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:09:42,970:INFO:EPOCH 9 - PROGRESS: at 28.66% examples, 247779 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:44,016:INFO:EPOCH 9 - PROGRESS: at 31.43% examples, 248912 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:09:45,098:INFO:EPOCH 9 - PROGRESS: at 34.36% examples, 251612 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:46,104:INFO:EPOCH 9 - PROGRESS: at 35.58% examples, 254319 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:47,104:INFO:EPOCH 9 - PROGRESS: at 37.23% examples, 253951 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:48,130:INFO:EPOCH 9 - PROGRESS: at 39.56% examples, 254435 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:09:49,164:INFO:EPOCH 9 - PROGRESS: at 41.57% examples, 257414 words/s, in_qsize 46, out_qsize 1
# 2020-09-08 16:09:50,187:INFO:EPOCH 9 - PROGRESS: at 43.06% examples, 257616 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:51,196:INFO:EPOCH 9 - PROGRESS: at 44.68% examples, 257290 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:09:52,208:INFO:EPOCH 9 - PROGRESS: at 46.50% examples, 257844 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:53,209:INFO:EPOCH 9 - PROGRESS: at 47.80% examples, 256230 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:54,221:INFO:EPOCH 9 - PROGRESS: at 49.51% examples, 254876 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:55,240:INFO:EPOCH 9 - PROGRESS: at 51.99% examples, 255235 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:56,245:INFO:EPOCH 9 - PROGRESS: at 54.28% examples, 254662 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:57,285:INFO:EPOCH 9 - PROGRESS: at 56.13% examples, 253153 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:58,301:INFO:EPOCH 9 - PROGRESS: at 57.98% examples, 253047 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:09:59,325:INFO:EPOCH 9 - PROGRESS: at 59.60% examples, 252403 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:00,331:INFO:EPOCH 9 - PROGRESS: at 61.15% examples, 250949 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:01,341:INFO:EPOCH 9 - PROGRESS: at 63.15% examples, 249561 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:10:02,424:INFO:EPOCH 9 - PROGRESS: at 66.90% examples, 249266 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:03,462:INFO:EPOCH 9 - PROGRESS: at 69.74% examples, 248092 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:04,556:INFO:EPOCH 9 - PROGRESS: at 72.71% examples, 247751 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:05,557:INFO:EPOCH 9 - PROGRESS: at 76.06% examples, 248182 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:06,562:INFO:EPOCH 9 - PROGRESS: at 78.77% examples, 247957 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:07,562:INFO:EPOCH 9 - PROGRESS: at 81.66% examples, 246978 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:08,567:INFO:EPOCH 9 - PROGRESS: at 84.70% examples, 247588 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:09,588:INFO:EPOCH 9 - PROGRESS: at 88.68% examples, 248930 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:10,634:INFO:EPOCH 9 - PROGRESS: at 92.65% examples, 249267 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:11,657:INFO:EPOCH 9 - PROGRESS: at 96.58% examples, 249889 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:12,300:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:10:12,304:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:10:12,306:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:10:12,308:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:10:12,329:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:10:12,331:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:10:12,344:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:10:12,354:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:10:12,360:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:10:12,378:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:10:12,397:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:10:12,402:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:10:12,428:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:10:12,441:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:10:12,455:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:10:12,459:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:10:12,462:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:10:12,470:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:10:12,476:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:10:12,482:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:10:12,488:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:10:12,503:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:10:12,536:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:10:12,574:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:10:12,576:INFO:EPOCH - 9 : training on 21113789 raw words (10775718 effective words) took 42.9s, 251071 effective words/s
# 2020-09-08 16:10:13,738:INFO:EPOCH 10 - PROGRESS: at 1.52% examples, 226957 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:14,758:INFO:EPOCH 10 - PROGRESS: at 3.10% examples, 236030 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:15,831:INFO:EPOCH 10 - PROGRESS: at 5.84% examples, 251994 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:16,865:INFO:EPOCH 10 - PROGRESS: at 7.76% examples, 257398 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:17,876:INFO:EPOCH 10 - PROGRESS: at 10.31% examples, 264053 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:18,914:INFO:EPOCH 10 - PROGRESS: at 12.40% examples, 260206 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:10:19,957:INFO:EPOCH 10 - PROGRESS: at 15.63% examples, 265896 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:20,997:INFO:EPOCH 10 - PROGRESS: at 18.39% examples, 264576 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:10:22,104:INFO:EPOCH 10 - PROGRESS: at 20.71% examples, 264022 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:10:23,111:INFO:EPOCH 10 - PROGRESS: at 23.17% examples, 266873 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:24,117:INFO:EPOCH 10 - PROGRESS: at 25.67% examples, 266517 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:25,182:INFO:EPOCH 10 - PROGRESS: at 28.11% examples, 261122 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:26,203:INFO:EPOCH 10 - PROGRESS: at 30.81% examples, 259489 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:27,211:INFO:EPOCH 10 - PROGRESS: at 32.99% examples, 257733 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:28,304:INFO:EPOCH 10 - PROGRESS: at 34.80% examples, 255633 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:29,345:INFO:EPOCH 10 - PROGRESS: at 35.70% examples, 254297 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:30,349:INFO:EPOCH 10 - PROGRESS: at 37.37% examples, 252442 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:10:31,363:INFO:EPOCH 10 - PROGRESS: at 39.50% examples, 252076 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:10:32,367:INFO:EPOCH 10 - PROGRESS: at 40.65% examples, 248219 words/s, in_qsize 48, out_qsize 1
# 2020-09-08 16:10:33,402:INFO:EPOCH 10 - PROGRESS: at 42.09% examples, 250085 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:34,408:INFO:EPOCH 10 - PROGRESS: at 43.73% examples, 247496 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:35,423:INFO:EPOCH 10 - PROGRESS: at 45.07% examples, 248177 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:36,534:INFO:EPOCH 10 - PROGRESS: at 46.69% examples, 246510 words/s, in_qsize 44, out_qsize 3
# 2020-09-08 16:10:37,568:INFO:EPOCH 10 - PROGRESS: at 48.39% examples, 247004 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:38,597:INFO:EPOCH 10 - PROGRESS: at 50.59% examples, 246377 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:39,606:INFO:EPOCH 10 - PROGRESS: at 52.53% examples, 245471 words/s, in_qsize 48, out_qsize 0
# 2020-09-08 16:10:40,609:INFO:EPOCH 10 - PROGRESS: at 54.93% examples, 245423 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:41,611:INFO:EPOCH 10 - PROGRESS: at 56.76% examples, 245017 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:42,630:INFO:EPOCH 10 - PROGRESS: at 58.39% examples, 244410 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:43,631:INFO:EPOCH 10 - PROGRESS: at 59.99% examples, 243749 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:44,652:INFO:EPOCH 10 - PROGRESS: at 61.91% examples, 244264 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:45,697:INFO:EPOCH 10 - PROGRESS: at 65.78% examples, 245994 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:46,761:INFO:EPOCH 10 - PROGRESS: at 69.67% examples, 246348 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:47,788:INFO:EPOCH 10 - PROGRESS: at 72.68% examples, 246630 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:48,811:INFO:EPOCH 10 - PROGRESS: at 76.59% examples, 248012 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:49,927:INFO:EPOCH 10 - PROGRESS: at 79.60% examples, 248026 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:50,948:INFO:EPOCH 10 - PROGRESS: at 83.04% examples, 248724 words/s, in_qsize 44, out_qsize 3
# 2020-09-08 16:10:51,971:INFO:EPOCH 10 - PROGRESS: at 87.04% examples, 249691 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:52,975:INFO:EPOCH 10 - PROGRESS: at 90.73% examples, 250176 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:54,001:INFO:EPOCH 10 - PROGRESS: at 94.76% examples, 250697 words/s, in_qsize 47, out_qsize 0
# 2020-09-08 16:10:55,024:INFO:EPOCH 10 - PROGRESS: at 98.30% examples, 250811 words/s, in_qsize 37, out_qsize 0
# 2020-09-08 16:10:55,235:INFO:worker thread finished; awaiting finish of 23 more threads
# 2020-09-08 16:10:55,244:INFO:worker thread finished; awaiting finish of 22 more threads
# 2020-09-08 16:10:55,260:INFO:worker thread finished; awaiting finish of 21 more threads
# 2020-09-08 16:10:55,287:INFO:worker thread finished; awaiting finish of 20 more threads
# 2020-09-08 16:10:55,304:INFO:worker thread finished; awaiting finish of 19 more threads
# 2020-09-08 16:10:55,313:INFO:worker thread finished; awaiting finish of 18 more threads
# 2020-09-08 16:10:55,325:INFO:worker thread finished; awaiting finish of 17 more threads
# 2020-09-08 16:10:55,328:INFO:worker thread finished; awaiting finish of 16 more threads
# 2020-09-08 16:10:55,329:INFO:worker thread finished; awaiting finish of 15 more threads
# 2020-09-08 16:10:55,335:INFO:worker thread finished; awaiting finish of 14 more threads
# 2020-09-08 16:10:55,342:INFO:worker thread finished; awaiting finish of 13 more threads
# 2020-09-08 16:10:55,350:INFO:worker thread finished; awaiting finish of 12 more threads
# 2020-09-08 16:10:55,384:INFO:worker thread finished; awaiting finish of 11 more threads
# 2020-09-08 16:10:55,389:INFO:worker thread finished; awaiting finish of 10 more threads
# 2020-09-08 16:10:55,393:INFO:worker thread finished; awaiting finish of 9 more threads
# 2020-09-08 16:10:55,398:INFO:worker thread finished; awaiting finish of 8 more threads
# 2020-09-08 16:10:55,419:INFO:worker thread finished; awaiting finish of 7 more threads
# 2020-09-08 16:10:55,450:INFO:worker thread finished; awaiting finish of 6 more threads
# 2020-09-08 16:10:55,452:INFO:worker thread finished; awaiting finish of 5 more threads
# 2020-09-08 16:10:55,456:INFO:worker thread finished; awaiting finish of 4 more threads
# 2020-09-08 16:10:55,466:INFO:worker thread finished; awaiting finish of 3 more threads
# 2020-09-08 16:10:55,481:INFO:worker thread finished; awaiting finish of 2 more threads
# 2020-09-08 16:10:55,517:INFO:worker thread finished; awaiting finish of 1 more threads
# 2020-09-08 16:10:55,529:INFO:worker thread finished; awaiting finish of 0 more threads
# 2020-09-08 16:10:55,530:INFO:EPOCH - 10 : training on 21113789 raw words (10776110 effective words) took 42.8s, 251787 effective words/s
# 2020-09-08 16:10:55,531:INFO:training on a 211137890 raw words (107757685 effective words) took 417.1s, 258331 effective words/s
# 2020-09-08 16:10:55,532:INFO:saving Word2Vec object under models/w2v_300_3.txt, separately None
# 2020-09-08 16:10:55,533:INFO:storing np array 'vectors' to models/w2v_300_3.txt.wv.vectors.npy
# 2020-09-08 16:10:55,722:INFO:not storing attribute vectors_norm
# 2020-09-08 16:10:55,724:INFO:storing np array 'syn1neg' to models/w2v_300_3.txt.trainables.syn1neg.npy
# 2020-09-08 16:10:55,920:INFO:not storing attribute cum_table
# 2020-09-08 16:10:56,095:INFO:saved models/w2v_300_3.txt
# w2v model done
# 0
# 2020-09-08 16:10:57,186:INFO:loading Word2Vec object from models/w2v_300_1.txt
# 2020-09-08 16:10:57,371:INFO:loading wv recursively from models/w2v_300_1.txt.wv.* with mmap=None
# 2020-09-08 16:10:57,373:INFO:setting ignored attribute vectors_norm to None
# 2020-09-08 16:10:57,375:INFO:loading vocabulary recursively from models/w2v_300_1.txt.vocabulary.* with mmap=None
# 2020-09-08 16:10:57,376:INFO:loading trainables recursively from models/w2v_300_1.txt.trainables.* with mmap=None
# 2020-09-08 16:10:57,379:INFO:setting ignored attribute cum_table to None
# 2020-09-08 16:10:57,382:INFO:loaded models/w2v_300_1.txt
# 100%|██████████| 7189/7189 [00:00<00:00, 49974.06it/s]
# 2020-09-08 16:10:57,589:INFO:loading Word2Vec object from models/w2v_300_3.txt
# 2020-09-08 16:10:57,703:INFO:loading wv recursively from models/w2v_300_3.txt.wv.* with mmap=None
# 2020-09-08 16:10:57,705:INFO:loading vectors from models/w2v_300_3.txt.wv.vectors.npy with mmap=None
# 2020-09-08 16:10:57,751:INFO:setting ignored attribute vectors_norm to None
# 2020-09-08 16:10:57,753:INFO:loading vocabulary recursively from models/w2v_300_3.txt.vocabulary.* with mmap=None
# 2020-09-08 16:10:57,754:INFO:loading trainables recursively from models/w2v_300_3.txt.trainables.* with mmap=None
# 2020-09-08 16:10:57,756:INFO:loading syn1neg from models/w2v_300_3.txt.trainables.syn1neg.npy with mmap=None
# null cnt 5
# 2020-09-08 16:10:57,804:INFO:setting ignored attribute cum_table to None
# 2020-09-08 16:10:57,806:INFO:loaded models/w2v_300_3.txt
# 100%|██████████| 28458/28458 [00:00<00:00, 42967.23it/s]
# null cnt 1202
# 31

# %% [markdown]
# # 构建抽取模型

# %% [markdown]
# #### 1.网络结构

# %%
from keras.initializers import *

def model_conv(emb1, emb3):
    '''
    注意这个inputs
    seq1、seq2分别是两个输入
    是否做emb可选可不选，
    这个就是我们之前训练已经得到的用于embedding的（embedding_matrix1， embedding_matrix2）
    '''
    K.clear_session()

    emb_layer_1 = Embedding(
        input_dim=emb1.shape[0],
        output_dim=emb1.shape[1],
        weights=[emb1],
        input_length=30,
        trainable=False
    )
    
    emb_layer_3 = Embedding(
        input_dim=emb3.shape[0],
        output_dim=emb3.shape[1],
        weights=[emb3],
        input_length=600,
        trainable=False
    )
    
    
    seq1 = Input(shape=(30,))
    seq3 = Input(shape=(600,))    
    
    x1 = emb_layer_1(seq1)
    x3 = emb_layer_3(seq3)
    
    sdrop=SpatialDropout1D(rate=0.2)

    x1 = sdrop(x1)
    x3 = sdrop(x3)
     
    x = Dropout(0.2)(Bidirectional(GRU(128, return_sequences=True))(x1))
    semantic = TimeDistributed(Dense(100, activation="tanh"))(x)
    merged_1 = Lambda(lambda x: K.max(x, axis=1), output_shape=(100,))(semantic)
    
    x = Dropout(0.2)(Bidirectional(GRU(128, return_sequences=True))(x3))
    semantic = TimeDistributed(Dense(100, activation="tanh"))(x)
    merged_3 = Lambda(lambda x: K.max(x, axis=1), output_shape=(100,))(semantic)
    
    
    x = Multiply()([merged_1, merged_3])
    
    x = Dropout(0.2)(Activation(activation="relu")(BatchNormalization()(Dense(1000)(x))))
    x = Activation(activation="relu")(BatchNormalization()(Dense(500)(x)))
    pred_1 = Dense(10, activation='softmax')(x)
    pred_2 = Dense(3, activation='softmax')(x)
    pred_3 = Dense(3, activation='softmax')(x)
    pred_4 = Dense(2, activation='softmax')(x)
    model = Model(inputs=[seq1, seq3], outputs=[pred_1, pred_2, pred_3, pred_4])
    model.compile(loss='categorical_crossentropy',
                  optimizer=Adam(lr=0.0001),metrics=["accuracy"])
    return model
gc.collect()
# Out:
# 0

# %%
model = model_conv(emb1, emb3)
model.summary()
l1 = to_categorical(train_data['label_1'], 10)
l2 = to_categorical(train_data['label_2'], 3)
l3 = to_categorical(train_data['label_3'], 3)
l4 = to_categorical(train_data['label_4'], 2)
model.fit([x1, x3],[l1, l2, l3, l4], batch_size=256, epochs=8, verbose=1, shuffle=True)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 30)]         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 600)]        0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 300)      2157000     input_1[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 600, 300)     8537700     input_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d (SpatialDropo multiple             0           embedding[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 30, 256)      330240      spatial_dropout1d[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 600, 256)     330240      spatial_dropout1d[1][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 30, 256)      0           bidirectional[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 600, 256)     0           bidirectional_1[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 30, 100)      25700       dropout[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 600, 100)     25700       dropout_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 100)          0           time_distributed[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 100)          0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 100)          0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         101000      multiply[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 1000)         4000        dense_2[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 1000)         0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1000)         0           activation[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 500)          500500      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 500)          2000        dense_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 500)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           5010        activation_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3)            1503        activation_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 3)            1503        activation_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 2)            1002        activation_1[0][0]
# ==================================================================================================
# Total params: 12,023,098
# Trainable params: 1,325,398
# Non-trainable params: 10,697,700
# __________________________________________________________________________________________________
# Epoch 1/8
# 107/107 [==============================] - 1831s 17s/step - loss: 2.7252 - dense_4_loss: 0.7166 - dense_5_loss: 0.8013 - dense_6_loss: 0.9522 - dense_7_loss: 0.2551 - dense_4_accuracy: 0.8142 - dense_5_accuracy: 0.6322 - dense_6_accuracy: 0.5784 - dense_7_accuracy: 0.9192
# Epoch 2/8
# 107/107 [==============================] - 2651s 25s/step - loss: 1.4218 - dense_4_loss: 0.1653 - dense_5_loss: 0.6561 - dense_6_loss: 0.5554 - dense_7_loss: 0.0449 - dense_4_accuracy: 0.9628 - dense_5_accuracy: 0.6883 - dense_6_accuracy: 0.7828 - dense_7_accuracy: 0.9986
# Epoch 3/8
# 107/107 [==============================] - 2849s 27s/step - loss: 1.2067 - dense_4_loss: 0.1229 - dense_5_loss: 0.5749 - dense_6_loss: 0.4846 - dense_7_loss: 0.0243 - dense_4_accuracy: 0.9713 - dense_5_accuracy: 0.7312 - dense_6_accuracy: 0.7971 - dense_7_accuracy: 0.9986
# Epoch 4/8
# 107/107 [==============================] - 2869s 27s/step - loss: 1.0446 - dense_4_loss: 0.1026 - dense_5_loss: 0.4989 - dense_6_loss: 0.4254 - dense_7_loss: 0.0176 - dense_4_accuracy: 0.9752 - dense_5_accuracy: 0.7804 - dense_6_accuracy: 0.8176 - dense_7_accuracy: 0.9986
# Epoch 5/8
# 107/107 [==============================] - 2877s 27s/step - loss: 0.9317 - dense_4_loss: 0.0902 - dense_5_loss: 0.4468 - dense_6_loss: 0.3800 - dense_7_loss: 0.0147 - dense_4_accuracy: 0.9769 - dense_5_accuracy: 0.8139 - dense_6_accuracy: 0.8365 - dense_7_accuracy: 0.9986
# Epoch 6/8
# 107/107 [==============================] - 2895s 27s/step - loss: 0.8594 - dense_4_loss: 0.0796 - dense_5_loss: 0.4115 - dense_6_loss: 0.3557 - dense_7_loss: 0.0126 - dense_4_accuracy: 0.9798 - dense_5_accuracy: 0.8305 - dense_6_accuracy: 0.8474 - dense_7_accuracy: 0.9986
# Epoch 7/8
# 107/107 [==============================] - 2897s 27s/step - loss: 0.8094 - dense_4_loss: 0.0727 - dense_5_loss: 0.3902 - dense_6_loss: 0.3351 - dense_7_loss: 0.0115 - dense_4_accuracy: 0.9817 - dense_5_accuracy: 0.8391 - dense_6_accuracy: 0.8550 - dense_7_accuracy: 0.9986
# Epoch 8/8
# 107/107 [==============================] - 2895s 27s/step - loss: 0.7554 - dense_4_loss: 0.0637 - dense_5_loss: 0.3603 - dense_6_loss: 0.3207 - dense_7_loss: 0.0106 - dense_4_accuracy: 0.9835 - dense_5_accuracy: 0.8531 - dense_6_accuracy: 0.8620 - dense_7_accuracy: 0.9986

# %%
#保存权重
model.save_weights('models/lstm_model.h5')

# %% [markdown]
# #### 2.保存结果

# %%
# 预测验证集
val_df["sample_id"]=val_df["sample_id"].astype(str)
val_result_for_pred = pd.merge(val_result, val_df, on='sample_id', how='left')
val_result_for_pred['text_1'] = val_result_for_pred['理财产品名称'].astype(str) + '_' + val_result_for_pred['产品发行方名称'].astype(str)
val_result_for_pred['text_2'] = val_result_for_pred['text'].astype(str)

val_result_for_pred['text_1'] = val_result_for_pred['text_1'].progress_apply(lambda row:' '.join(jieba.lcut(str(row))))
val_result_for_pred['text_2'] = val_result_for_pred['text_2'].progress_apply(lambda row:' '.join(jieba.lcut(str(row))))

x1 = token_1.texts_to_sequences(val_result_for_pred['text_1'])
x1 = pad_sequences(x1, maxlen=30, value=0)
x3 = token_3.texts_to_sequences(val_result_for_pred['text_2'])
x3 = pad_sequences(x3, maxlen=600, value=0)
pred_result = model.predict([x1, x3], batch_size=1024, verbose=1)
pred_1 = label_1.inverse_transform(np.argmax(pred_result[0], axis=1))
pred_2 = label_2.inverse_transform(np.argmax(pred_result[1], axis=1))
pred_3 = label_3.inverse_transform(np.argmax(pred_result[2], axis=1))
pred_4 = label_4.inverse_transform(np.argmax(pred_result[3], axis=1))
# Out:
# 100%|██████████| 3868/3868 [00:00<00:00, 5377.75it/s]
# 100%|██████████| 3868/3868 [01:41<00:00, 38.22it/s]
# 4/4 [==============================] - 34s 9s/step

# %%
val_result['理财类型'] = pred_1
val_result['资金来源'] = pred_2
val_result['实际购买公司和上市公司关系'] = pred_3
val_result['买卖方是否有关联关系'] = pred_4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-33bb5074b888> in <module>
# ----> 1 val_result['理财类型'] = pred_1
#       2 val_result['资金来源'] = pred_2
#       3 val_result['实际购买公司和上市公司关系'] = pred_3
#       4 val_result['买卖方是否有关联关系'] = pred_4
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# C:\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %% [markdown]
# #### 3.离线验证评估

# %%
# 计算线下f1
# R（召回率）=抽取正确的记录数量/（抽取正确的目标数量+漏抽取的记录数量）
# P（准确率）=抽取正确的记录数量/（抽取错误的记录数量+抽取正确的记录数量）
def get_F1(val_pred, val_true):
    val_pred = list(val_pred)
    val_true = list(val_true)
    curr = list(set(val_pred).intersection(set(val_true)))
    R = len(curr)/len(val_true)
    P = len(curr)/len(val_pred)
    return 2*P*R/(P+R)

train_outputs["sample_id"]=train_outputs["sample_id"].astype(str)
r = pd.merge(val_df[['sample_id']], train_outputs, on='sample_id', how='left')
val_true = r['sample_id'].astype(str) + r['认购日期'].astype(str) + r['理财产品名称'].astype(str) + r['理财类型'].astype(str) + r['认购金额(万元)'].astype(str) + r['产品起息日'].astype(str)+ r['产品到息日'].astype(str) + r['产品期限'].astype(str) + r['资金来源'].astype(str) + r['实际购买公司名称'].astype(str) + r['实际购买公司和上市公司关系'].astype(str) + r['买卖方是否有关联关系'].astype(str) + r['公告日期'].astype(str)

r = val_result
val_pred = r['sample_id'].astype(str) + r['认购日期'].astype(str) + r['理财产品名称'].astype(str) + r['理财类型'].astype(str) + r['认购金额(万元)'].astype(str) + r['产品起息日'].astype(str)+ r['产品到息日'].astype(str) + r['产品期限'].astype(str) + r['资金来源'].astype(str) + r['实际购买公司名称'].astype(str) + r['实际购买公司和上市公司关系'].astype(str) + r['买卖方是否有关联关系'].astype(str) + r['公告日期'].astype(str)

score = get_F1(val_pred, val_true)
score
# Out:
# 0.0551883328087294

# %%
val_true_file=pl.Path("results/val_true.csv")
val_pred_file=pl.Path("results/val_pred.csv")

tr_true_file=pl.Path("results/tr_true.csv")
val_result.copy().sort_values(by="sample_id").sort_index(axis=1).to_csv(val_pred_file,index=None)
pd.merge(val_df[['sample_id']], train_outputs, on='sample_id', how='left').sort_index(axis=1).sort_values(by="sample_id").to_csv(val_true_file,index=None)
pd.merge(train_df[['sample_id']], train_outputs, on='sample_id', how='left').sort_index(axis=1).sort_values(by="sample_id").to_csv(tr_true_file,index=None)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-8e1747814424> in <module>
#       5
#       6 val_result.copy().sort_values(by="sample_id").sort_index(axis=1).to_csv(val_pred_file,index=None)
# ----> 7 pd.merge(val_df[['sample_id']], train_outputs, on='sample_id', how='left').sort_index(axis=1).sort_values(by="sample_id").to_csv(val_true_file,index=None)
#       8 pd.merge(train_df[['sample_id']], train_outputs, on='sample_id', how='left').sort_index(axis=1).sort_values(by="sample_id").to_csv(tr_true_file,index=None)
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     629         # validate the merge keys dtypes. We may need to coerce
#     630         # to avoid incompat dtypes
# --> 631         self._maybe_coerce_merge_keys()
#     632
#     633         # If argument passed to validate,
#
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _maybe_coerce_merge_keys(self)
#    1144                     inferred_right in string_types and inferred_left not in string_types
#    1145                 ):
# -> 1146                     raise ValueError(msg)
#    1147
#    1148             # datetimelikes must match exactly
#
# ValueError: You are trying to merge on object and int64 columns. If you wish to proceed you should use pd.concat

# %% [markdown]
# #### 4.最终输出结果

# %%
# 预测测试集
test_df["sample_id"]=test_df["sample_id"].astype(str)
test_result_for_pred = pd.merge(test_result, test_df, on='sample_id', how='left')
test_result_for_pred['text_1'] = test_result_for_pred['理财产品名称'].astype(str) + '_' + test_result_for_pred['产品发行方名称'].astype(str)
test_result_for_pred['text_2'] = test_result_for_pred['text'].astype(str)

test_result_for_pred['text_1'] = test_result_for_pred['text_1'].progress_apply(lambda row:' '.join(jieba.lcut(str(row))))
test_result_for_pred['text_2'] = test_result_for_pred['text_2'].progress_apply(lambda row:' '.join(jieba.lcut(str(row))))

x1 = token_1.texts_to_sequences(test_result_for_pred['text_1'])
x1 = pad_sequences(x1, maxlen=30, value=0)
x3 = token_3.texts_to_sequences(test_result_for_pred['text_2'])
x3 = pad_sequences(x3, maxlen=600, value=0)
pred_result = model.predict([x1, x3], batch_size=1024, verbose=1)
pred_1 = label_1.inverse_transform(np.argmax(pred_result[0], axis=1))
pred_2 = label_2.inverse_transform(np.argmax(pred_result[1], axis=1))
pred_3 = label_3.inverse_transform(np.argmax(pred_result[2], axis=1))
pred_4 = label_4.inverse_transform(np.argmax(pred_result[3], axis=1))

test_result['理财类型'] = pred_1
test_result['资金来源'] = pred_2
test_result['实际购买公司和上市公司关系'] = pred_3
test_result['买卖方是否有关联关系'] = pred_4
# Out:
# 100%|██████████| 11406/11406 [00:01<00:00, 5918.93it/s]
# 100%|██████████| 11406/11406 [03:30<00:00, 54.24it/s]
# 12/12 [==============================] - 115s 10s/step

# %%
test_result.to_csv('results/re_lstm_base.csv',encoding="utf8", index=False)
test_result.to_excel('results/re_lstm_base.xlsx',encoding="gb18030", index=False)

# %%
files_num=int(test_df.shape[0]/4)
test_time["sample_id"]=test_time["sample_id"].astype(str)

# test_time.shape
# test_time.dropna(subset=["公告日期"]).shape
import random
for i in range(1,20):
    random_seed=random.randint(0,10000)
    random_test_df = test_df.sample(frac=1, random_state=random_seed)
    change_df=random_test_df[:files_num]
    stable_df=random_test_df[files_num:]
    random_test_time=pd.merge(change_df,test_time,on=["sample_id"])
    random_test_time.shape
    random_test_time=random_test_time.dropna(subset=["公告日期"])
    random_test_time.shape
    random_test_time["公告日期"]=random_test_time["公告日期"].map(lambda x:datetime.datetime.strftime(datetime.datetime.strptime(str(x.replace("\r","")), '%Y-%m-%d'),'%Y-%m-%d'))
# Out:
# (2165, 5)
# (2158, 5)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-19939d1d7bf3> in <module>
#      14     random_test_time=random_test_time.dropna(subset=["公告日期"])
#      15     random_test_time.shape
# ---> 16     random_test_time["公告日期"]=random_test_time["公告日期"].map(lambda x:datetime.datetime.strftime(datetime.datetime.strptime(str(x.replace("\r","")), '%Y-%m-%d'),'%Y-%m-%d'))
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# C:\Anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#    1143
#    1144         # mapper is a function
# -> 1145         new_values = map_f(values, mapper)
#    1146
#    1147         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-72-19939d1d7bf3> in <lambda>(x)
#      14     random_test_time=random_test_time.dropna(subset=["公告日期"])
#      15     random_test_time.shape
# ---> 16     random_test_time["公告日期"]=random_test_time["公告日期"].map(lambda x:datetime.datetime.strftime(datetime.datetime.strptime(str(x.replace("\r","")), '%Y-%m-%d'),'%Y-%m-%d'))
#
# C:\Anaconda3\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# C:\Anaconda3\lib\_strptime.py in _strptime(data_string, format)
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
# --> 352         raise ValueError("unconverted data remains: %s" %
#     353                           data_string[found.end():])
#     354
#
# ValueError: unconverted data remains: 2
